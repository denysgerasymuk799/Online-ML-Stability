# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
import pandas as pd
import seaborn as sns

from river import compose
from river import preprocessing
from river import ensemble
from sklearn.model_selection import train_test_split

from source.config import *
from source.stability.incremental_stability_analyzer import IncrementalStabilityAnalyzer
from source.utils.incremental_model_utils import train_incremental_model
from source.data_loaders.folktables_dataset_from_pd import FolktablesDatasetFromPandas

# %%
sns.set(rc={'figure.figsize':(15, 5)})
dataset_name = 'folktables'
state = 'LA'
dataset_config = DATASETS_CONFIG[dataset_name]
TARGET_COLUMN = dataset_config['target_column']

# %%
# Creating a data frame
df = pd.read_csv(f"../../datasets/folktables-{state}-2018.csv", delimiter=',')
df.head()
# Out:
#    AGEP  SCHL  MAR  RELP  DIS  ESP  CIT  MIG  MIL  ANC  NATIVITY  DEAR  DEYE  \
# 0    29    18    5    16    2    0    1    1    4    2         1     2     2
# 1    17    13    5    16    2    0    1    1    4    1         1     2     2
# 2    37    13    5    16    2    0    1    1    4    1         1     2     2
# 3    86    12    2    16    1    0    1    1    4    1         1     2     1
# 4    22    19    5    17    2    0    1    1    4    1         1     2     2
#
#    DREM  SEX  RAC1P  ESR
# 0     2    1      1    0
# 1     2    1      2    0
# 2     2    1      1    0
# 3     2    2      2    0
# 4     2    2      1    0

# %%
df.shape
# Out:
# (43588, 17)

# %%
df.columns
# Out:
# Index(['AGEP', 'SCHL', 'MAR', 'RELP', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
#        'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'SEX', 'RAC1P', 'ESR'],
#       dtype='object')

# %%
df['ESR'].value_counts()
# Out:
# 0    25363
# 1    18225
# Name: ESR, dtype: int64

# %%
dataset_size = df.shape[0]
test_size = int(TEST_FRACTION * dataset_size)
validation_size = test_size

train_cv_df, test_df = train_test_split(df, test_size=test_size, random_state=SEED)
train_df, cv_df = train_test_split(train_cv_df, test_size=validation_size, random_state=SEED)
print("train_df shape: ", train_df.shape)
print("cv_df shape: ", cv_df.shape)
print("test_df shape: ", test_df.shape)
# Out:
# train_df shape:  (26154, 17)
# cv_df shape:  (8717, 17)
# test_df shape:  (8717, 17)

# %%
train_dataset = FolktablesDatasetFromPandas(pd_dataset=train_df)

# %%
numerical_features = dataset_config['numerical_features']
categorical_features = [feature for feature in df.columns if feature not in numerical_features + [TARGET_COLUMN]]

categorical_features
# Out:
# ['MAR',
#  'RELP',
#  'DIS',
#  'ESP',
#  'CIT',
#  'MIG',
#  'MIL',
#  'ANC',
#  'NATIVITY',
#  'DEAR',
#  'DEYE',
#  'DREM',
#  'SEX',
#  'RAC1P']

# %% [markdown]
# ### Apply data transformations

# %%
def get_transform_pipeline(categorical_features, numerical_features):
    transform_pipeline = compose.Select(categorical_features[0])
    for feature in categorical_features[1:]:
        transform_pipeline += compose.Select(feature)
    transform_pipeline |= preprocessing.OneHotEncoder()

    for feature in numerical_features:
        transform_pipeline += compose.Select(feature)
    transform_pipeline |= preprocessing.MinMaxScaler()

    return transform_pipeline

# %%
transform_pipeline = get_transform_pipeline(categorical_features, numerical_features)

for idx, (x, y) in enumerate(train_dataset):
    print(f'Initial features: {x}\n')
    x = transform_pipeline.transform_one(x)
    print(f'Transformed features: {x}\n\n')
    if idx + 1 == 10:
        break
# Out:
# Initial features: {'AGEP': 93, 'SCHL': 19, 'MAR': '3', 'RELP': '0', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '4', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '1', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 58, 'SCHL': 23, 'MAR': '3', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 1.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 69, 'SCHL': 17, 'MAR': '3', 'RELP': '0', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.3142857142857143, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 28, 'SCHL': 22, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '4', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.8333333333333334, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 1.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_1': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 35, 'SCHL': 16, 'MAR': '5', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '2'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.1076923076923077, 'RAC1P_2': 0.0, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_1': 0.0, 'MAR_3': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 66, 'SCHL': 16, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.5846153846153846, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 41, 'SCHL': 18, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.2857142857142857, 'AGEP': 0.2, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_1': 1.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'ANC_2': 1.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 15, 'SCHL': 11, 'MAR': '5', 'RELP': '2', 'DIS': '1', 'ESP': '2', 'CIT': '1', 'MIG': '1', 'MIL': '0', 'ANC': '3', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '1', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_1': 1.0, 'SEX_2': 0.0, 'DREM_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'ANC_3': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_0': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'ESP_2': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'MAR_1': 0.0, 'MAR_3': 0.0, 'MAR_5': 1.0}
#
#
# Initial features: {'AGEP': 51, 'SCHL': 16, 'MAR': '1', 'RELP': '1', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '2'}
#
# Transformed features: {'SCHL': 0.4166666666666667, 'AGEP': 0.46153846153846156, 'RAC1P_2': 1.0, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_1': 0.0, 'DREM_2': 1.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 1.0, 'ANC_3': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_0': 0.0, 'MIL_4': 1.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 1.0, 'ESP_2': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_1': 0.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 73, 'SCHL': 15, 'MAR': '1', 'RELP': '1', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '1', 'DREM': '1', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.3333333333333333, 'AGEP': 0.7435897435897436, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_1': 1.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 1.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 1.0, 'ANC_3': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_0': 0.0, 'MIL_4': 1.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 1.0, 'ESP_2': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_1': 0.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0, 'MAR_5': 0.0}

# %% [markdown]
# ### Analyze stability of Adaptive Random Forest classifier

# %%
def get_base_model():
    return ensemble.AdaptiveRandomForestClassifier(n_models=10, seed=SEED, split_criterion='gini'), 'Adaptive Random Forest'

# %%
base_model, base_model_name = get_base_model()

# Conduct model training
base_model = train_incremental_model(base_model, train_dataset, train_df.shape[0])
# Out:
# 2022-11-18 00:32:56 incremental_model_utils.py INFO    : Iteration 1000/26154 -- Accuracy: 75.08%; WeightedF1: 74.89%
# 2022-11-18 00:32:57 incremental_model_utils.py INFO    : Iteration 2000/26154 -- Accuracy: 77.29%; WeightedF1: 77.28%
# 2022-11-18 00:32:59 incremental_model_utils.py INFO    : Iteration 3000/26154 -- Accuracy: 77.83%; WeightedF1: 77.90%
# 2022-11-18 00:33:00 incremental_model_utils.py INFO    : Iteration 4000/26154 -- Accuracy: 78.37%; WeightedF1: 78.46%
# 2022-11-18 00:33:01 incremental_model_utils.py INFO    : Iteration 5000/26154 -- Accuracy: 78.82%; WeightedF1: 78.89%
# 2022-11-18 00:33:02 incremental_model_utils.py INFO    : Iteration 6000/26154 -- Accuracy: 78.73%; WeightedF1: 78.82%
# 2022-11-18 00:33:04 incremental_model_utils.py INFO    : Iteration 7000/26154 -- Accuracy: 78.93%; WeightedF1: 79.02%
# 2022-11-18 00:33:05 incremental_model_utils.py INFO    : Iteration 8000/26154 -- Accuracy: 79.07%; WeightedF1: 79.16%
# 2022-11-18 00:33:07 incremental_model_utils.py INFO    : Iteration 9000/26154 -- Accuracy: 79.14%; WeightedF1: 79.24%
# 2022-11-18 00:33:08 incremental_model_utils.py INFO    : Iteration 10000/26154 -- Accuracy: 79.02%; WeightedF1: 79.10%
# 2022-11-18 00:33:10 incremental_model_utils.py INFO    : Iteration 11000/26154 -- Accuracy: 79.16%; WeightedF1: 79.24%
# 2022-11-18 00:33:12 incremental_model_utils.py INFO    : Iteration 12000/26154 -- Accuracy: 79.32%; WeightedF1: 79.41%
# 2022-11-18 00:33:13 incremental_model_utils.py INFO    : Iteration 13000/26154 -- Accuracy: 79.27%; WeightedF1: 79.35%
# 2022-11-18 00:33:15 incremental_model_utils.py INFO    : Iteration 14000/26154 -- Accuracy: 79.34%; WeightedF1: 79.42%
# 2022-11-18 00:33:16 incremental_model_utils.py INFO    : Iteration 15000/26154 -- Accuracy: 79.38%; WeightedF1: 79.46%
# 2022-11-18 00:33:18 incremental_model_utils.py INFO    : Iteration 16000/26154 -- Accuracy: 79.50%; WeightedF1: 79.58%
# 2022-11-18 00:33:19 incremental_model_utils.py INFO    : Iteration 17000/26154 -- Accuracy: 79.59%; WeightedF1: 79.66%
# 2022-11-18 00:33:21 incremental_model_utils.py INFO    : Iteration 18000/26154 -- Accuracy: 79.70%; WeightedF1: 79.78%
# 2022-11-18 00:33:22 incremental_model_utils.py INFO    : Iteration 19000/26154 -- Accuracy: 79.83%; WeightedF1: 79.90%
# 2022-11-18 00:33:24 incremental_model_utils.py INFO    : Iteration 20000/26154 -- Accuracy: 79.96%; WeightedF1: 80.04%
# 2022-11-18 00:33:25 incremental_model_utils.py INFO    : Iteration 21000/26154 -- Accuracy: 79.94%; WeightedF1: 80.01%
# 2022-11-18 00:33:27 incremental_model_utils.py INFO    : Iteration 22000/26154 -- Accuracy: 79.91%; WeightedF1: 79.99%
# 2022-11-18 00:33:28 incremental_model_utils.py INFO    : Iteration 23000/26154 -- Accuracy: 80.04%; WeightedF1: 80.12%
# 2022-11-18 00:33:30 incremental_model_utils.py INFO    : Iteration 24000/26154 -- Accuracy: 80.07%; WeightedF1: 80.15%
# 2022-11-18 00:33:31 incremental_model_utils.py INFO    : Iteration 25000/26154 -- Accuracy: 80.16%; WeightedF1: 80.24%
# 2022-11-18 00:33:33 incremental_model_utils.py INFO    : Iteration 26000/26154 -- Accuracy: 80.20%; WeightedF1: 80.28%
# Metrics after incremental model training:
# Accuracy: 80.21%
# WeightedF1: 80.29%

# %%
stability_analyzer = IncrementalStabilityAnalyzer(base_model,
                                                  base_model_name=base_model_name,
                                                  train_pd_dataset=cv_df,
                                                  test_pd_dataset=test_df,
                                                  test_y_true=test_df[TARGET_COLUMN],
                                                  dataset_reader=FolktablesDatasetFromPandas,
                                                  dataset_name=dataset_name + '_LA',
                                                  n_estimators=100)

# %%
stability_analyzer.measure_stability_metrics(make_plots=True)
# Out:
# 2022-11-18 00:35:55 base_stability_analyzer.py INFO    : Start testing of classifier 1 / 100
# 2022-11-18 00:36:04 base_stability_analyzer.py INFO    : Classifier 1 / 100 was tested
# 2022-11-18 00:36:04 base_stability_analyzer.py INFO    : Start testing of classifier 2 / 100
# 2022-11-18 00:36:13 base_stability_analyzer.py INFO    : Classifier 2 / 100 was tested
# 2022-11-18 00:36:13 base_stability_analyzer.py INFO    : Start testing of classifier 3 / 100
# 2022-11-18 00:36:23 base_stability_analyzer.py INFO    : Classifier 3 / 100 was tested
# 2022-11-18 00:36:23 base_stability_analyzer.py INFO    : Start testing of classifier 4 / 100
# 2022-11-18 00:36:32 base_stability_analyzer.py INFO    : Classifier 4 / 100 was tested
# 2022-11-18 00:36:32 base_stability_analyzer.py INFO    : Start testing of classifier 5 / 100
# 2022-11-18 00:36:42 base_stability_analyzer.py INFO    : Classifier 5 / 100 was tested
# 2022-11-18 00:36:42 base_stability_analyzer.py INFO    : Start testing of classifier 6 / 100
# 2022-11-18 00:36:51 base_stability_analyzer.py INFO    : Classifier 6 / 100 was tested
# 2022-11-18 00:36:51 base_stability_analyzer.py INFO    : Start testing of classifier 7 / 100
# 2022-11-18 00:37:00 base_stability_analyzer.py INFO    : Classifier 7 / 100 was tested
# 2022-11-18 00:37:00 base_stability_analyzer.py INFO    : Start testing of classifier 8 / 100
# 2022-11-18 00:37:09 base_stability_analyzer.py INFO    : Classifier 8 / 100 was tested
# 2022-11-18 00:37:09 base_stability_analyzer.py INFO    : Start testing of classifier 9 / 100
# 2022-11-18 00:37:19 base_stability_analyzer.py INFO    : Classifier 9 / 100 was tested
# 2022-11-18 00:37:19 base_stability_analyzer.py INFO    : Start testing of classifier 10 / 100
# 2022-11-18 00:37:28 base_stability_analyzer.py INFO    : Classifier 10 / 100 was tested
# 2022-11-18 00:37:28 base_stability_analyzer.py INFO    : Start testing of classifier 11 / 100
# 2022-11-18 00:37:37 base_stability_analyzer.py INFO    : Classifier 11 / 100 was tested
# 2022-11-18 00:37:37 base_stability_analyzer.py INFO    : Start testing of classifier 12 / 100
# 2022-11-18 00:37:46 base_stability_analyzer.py INFO    : Classifier 12 / 100 was tested
# 2022-11-18 00:37:46 base_stability_analyzer.py INFO    : Start testing of classifier 13 / 100
# 2022-11-18 00:37:56 base_stability_analyzer.py INFO    : Classifier 13 / 100 was tested
# 2022-11-18 00:37:56 base_stability_analyzer.py INFO    : Start testing of classifier 14 / 100
# 2022-11-18 00:38:05 base_stability_analyzer.py INFO    : Classifier 14 / 100 was tested
# 2022-11-18 00:38:05 base_stability_analyzer.py INFO    : Start testing of classifier 15 / 100
# 2022-11-18 00:38:14 base_stability_analyzer.py INFO    : Classifier 15 / 100 was tested
# 2022-11-18 00:38:14 base_stability_analyzer.py INFO    : Start testing of classifier 16 / 100
# 2022-11-18 00:38:23 base_stability_analyzer.py INFO    : Classifier 16 / 100 was tested
# 2022-11-18 00:38:23 base_stability_analyzer.py INFO    : Start testing of classifier 17 / 100
# 2022-11-18 00:38:33 base_stability_analyzer.py INFO    : Classifier 17 / 100 was tested
# 2022-11-18 00:38:33 base_stability_analyzer.py INFO    : Start testing of classifier 18 / 100
# 2022-11-18 00:38:41 base_stability_analyzer.py INFO    : Classifier 18 / 100 was tested
# 2022-11-18 00:38:41 base_stability_analyzer.py INFO    : Start testing of classifier 19 / 100
# 2022-11-18 00:38:50 base_stability_analyzer.py INFO    : Classifier 19 / 100 was tested
# 2022-11-18 00:38:50 base_stability_analyzer.py INFO    : Start testing of classifier 20 / 100
# 2022-11-18 00:38:59 base_stability_analyzer.py INFO    : Classifier 20 / 100 was tested
# 2022-11-18 00:38:59 base_stability_analyzer.py INFO    : Start testing of classifier 21 / 100
# 2022-11-18 00:39:07 base_stability_analyzer.py INFO    : Classifier 21 / 100 was tested
# 2022-11-18 00:39:07 base_stability_analyzer.py INFO    : Start testing of classifier 22 / 100
# 2022-11-18 00:39:16 base_stability_analyzer.py INFO    : Classifier 22 / 100 was tested
# 2022-11-18 00:39:16 base_stability_analyzer.py INFO    : Start testing of classifier 23 / 100
# 2022-11-18 00:39:24 base_stability_analyzer.py INFO    : Classifier 23 / 100 was tested
# 2022-11-18 00:39:24 base_stability_analyzer.py INFO    : Start testing of classifier 24 / 100
# 2022-11-18 00:39:32 base_stability_analyzer.py INFO    : Classifier 24 / 100 was tested
# 2022-11-18 00:39:32 base_stability_analyzer.py INFO    : Start testing of classifier 25 / 100
# 2022-11-18 00:39:40 base_stability_analyzer.py INFO    : Classifier 25 / 100 was tested
# 2022-11-18 00:39:40 base_stability_analyzer.py INFO    : Start testing of classifier 26 / 100
# 2022-11-18 00:39:48 base_stability_analyzer.py INFO    : Classifier 26 / 100 was tested
# 2022-11-18 00:39:48 base_stability_analyzer.py INFO    : Start testing of classifier 27 / 100
# 2022-11-18 00:39:57 base_stability_analyzer.py INFO    : Classifier 27 / 100 was tested
# 2022-11-18 00:39:57 base_stability_analyzer.py INFO    : Start testing of classifier 28 / 100
# 2022-11-18 00:40:05 base_stability_analyzer.py INFO    : Classifier 28 / 100 was tested
# 2022-11-18 00:40:05 base_stability_analyzer.py INFO    : Start testing of classifier 29 / 100
# 2022-11-18 00:40:13 base_stability_analyzer.py INFO    : Classifier 29 / 100 was tested
# 2022-11-18 00:40:13 base_stability_analyzer.py INFO    : Start testing of classifier 30 / 100
# 2022-11-18 00:40:22 base_stability_analyzer.py INFO    : Classifier 30 / 100 was tested
# 2022-11-18 00:40:22 base_stability_analyzer.py INFO    : Start testing of classifier 31 / 100
# 2022-11-18 00:40:30 base_stability_analyzer.py INFO    : Classifier 31 / 100 was tested
# 2022-11-18 00:40:30 base_stability_analyzer.py INFO    : Start testing of classifier 32 / 100
# 2022-11-18 00:40:39 base_stability_analyzer.py INFO    : Classifier 32 / 100 was tested
# 2022-11-18 00:40:39 base_stability_analyzer.py INFO    : Start testing of classifier 33 / 100
# 2022-11-18 00:40:48 base_stability_analyzer.py INFO    : Classifier 33 / 100 was tested
# 2022-11-18 00:40:48 base_stability_analyzer.py INFO    : Start testing of classifier 34 / 100
# 2022-11-18 00:40:56 base_stability_analyzer.py INFO    : Classifier 34 / 100 was tested
# 2022-11-18 00:40:56 base_stability_analyzer.py INFO    : Start testing of classifier 35 / 100
# 2022-11-18 00:41:05 base_stability_analyzer.py INFO    : Classifier 35 / 100 was tested
# 2022-11-18 00:41:05 base_stability_analyzer.py INFO    : Start testing of classifier 36 / 100
# 2022-11-18 00:41:14 base_stability_analyzer.py INFO    : Classifier 36 / 100 was tested
# 2022-11-18 00:41:14 base_stability_analyzer.py INFO    : Start testing of classifier 37 / 100
# 2022-11-18 00:41:22 base_stability_analyzer.py INFO    : Classifier 37 / 100 was tested
# 2022-11-18 00:41:22 base_stability_analyzer.py INFO    : Start testing of classifier 38 / 100
# 2022-11-18 00:41:30 base_stability_analyzer.py INFO    : Classifier 38 / 100 was tested
# 2022-11-18 00:41:30 base_stability_analyzer.py INFO    : Start testing of classifier 39 / 100
# 2022-11-18 00:41:38 base_stability_analyzer.py INFO    : Classifier 39 / 100 was tested
# 2022-11-18 00:41:38 base_stability_analyzer.py INFO    : Start testing of classifier 40 / 100
# 2022-11-18 00:41:46 base_stability_analyzer.py INFO    : Classifier 40 / 100 was tested
# 2022-11-18 00:41:46 base_stability_analyzer.py INFO    : Start testing of classifier 41 / 100
# 2022-11-18 00:41:54 base_stability_analyzer.py INFO    : Classifier 41 / 100 was tested
# 2022-11-18 00:41:54 base_stability_analyzer.py INFO    : Start testing of classifier 42 / 100
# 2022-11-18 00:42:03 base_stability_analyzer.py INFO    : Classifier 42 / 100 was tested
# 2022-11-18 00:42:03 base_stability_analyzer.py INFO    : Start testing of classifier 43 / 100
# 2022-11-18 00:42:12 base_stability_analyzer.py INFO    : Classifier 43 / 100 was tested
# 2022-11-18 00:42:12 base_stability_analyzer.py INFO    : Start testing of classifier 44 / 100
# 2022-11-18 00:42:20 base_stability_analyzer.py INFO    : Classifier 44 / 100 was tested
# 2022-11-18 00:42:20 base_stability_analyzer.py INFO    : Start testing of classifier 45 / 100
# 2022-11-18 00:42:29 base_stability_analyzer.py INFO    : Classifier 45 / 100 was tested
# 2022-11-18 00:42:29 base_stability_analyzer.py INFO    : Start testing of classifier 46 / 100
# 2022-11-18 00:42:39 base_stability_analyzer.py INFO    : Classifier 46 / 100 was tested
# 2022-11-18 00:42:39 base_stability_analyzer.py INFO    : Start testing of classifier 47 / 100
# 2022-11-18 00:42:48 base_stability_analyzer.py INFO    : Classifier 47 / 100 was tested
# 2022-11-18 00:42:48 base_stability_analyzer.py INFO    : Start testing of classifier 48 / 100
# 2022-11-18 00:42:57 base_stability_analyzer.py INFO    : Classifier 48 / 100 was tested
# 2022-11-18 00:42:57 base_stability_analyzer.py INFO    : Start testing of classifier 49 / 100
# 2022-11-18 00:43:06 base_stability_analyzer.py INFO    : Classifier 49 / 100 was tested
# 2022-11-18 00:43:06 base_stability_analyzer.py INFO    : Start testing of classifier 50 / 100
# 2022-11-18 00:43:15 base_stability_analyzer.py INFO    : Classifier 50 / 100 was tested
# 2022-11-18 00:43:15 base_stability_analyzer.py INFO    : Start testing of classifier 51 / 100
# 2022-11-18 00:43:25 base_stability_analyzer.py INFO    : Classifier 51 / 100 was tested
# 2022-11-18 00:43:25 base_stability_analyzer.py INFO    : Start testing of classifier 52 / 100
# 2022-11-18 00:43:43 base_stability_analyzer.py INFO    : Classifier 52 / 100 was tested
# 2022-11-18 00:43:43 base_stability_analyzer.py INFO    : Start testing of classifier 53 / 100
# 2022-11-18 00:43:52 base_stability_analyzer.py INFO    : Classifier 53 / 100 was tested
# 2022-11-18 00:43:52 base_stability_analyzer.py INFO    : Start testing of classifier 54 / 100
# 2022-11-18 00:44:01 base_stability_analyzer.py INFO    : Classifier 54 / 100 was tested
# 2022-11-18 00:44:01 base_stability_analyzer.py INFO    : Start testing of classifier 55 / 100
# 2022-11-18 00:44:10 base_stability_analyzer.py INFO    : Classifier 55 / 100 was tested
# 2022-11-18 00:44:10 base_stability_analyzer.py INFO    : Start testing of classifier 56 / 100
# 2022-11-18 00:44:18 base_stability_analyzer.py INFO    : Classifier 56 / 100 was tested
# 2022-11-18 00:44:18 base_stability_analyzer.py INFO    : Start testing of classifier 57 / 100
# 2022-11-18 00:44:26 base_stability_analyzer.py INFO    : Classifier 57 / 100 was tested
# 2022-11-18 00:44:26 base_stability_analyzer.py INFO    : Start testing of classifier 58 / 100
# 2022-11-18 00:44:34 base_stability_analyzer.py INFO    : Classifier 58 / 100 was tested
# 2022-11-18 00:44:34 base_stability_analyzer.py INFO    : Start testing of classifier 59 / 100
# 2022-11-18 00:44:44 base_stability_analyzer.py INFO    : Classifier 59 / 100 was tested
# 2022-11-18 00:44:44 base_stability_analyzer.py INFO    : Start testing of classifier 60 / 100
# 2022-11-18 00:44:53 base_stability_analyzer.py INFO    : Classifier 60 / 100 was tested
# 2022-11-18 00:44:53 base_stability_analyzer.py INFO    : Start testing of classifier 61 / 100
# 2022-11-18 00:45:02 base_stability_analyzer.py INFO    : Classifier 61 / 100 was tested
# 2022-11-18 00:45:02 base_stability_analyzer.py INFO    : Start testing of classifier 62 / 100
# 2022-11-18 00:45:10 base_stability_analyzer.py INFO    : Classifier 62 / 100 was tested
# 2022-11-18 00:45:10 base_stability_analyzer.py INFO    : Start testing of classifier 63 / 100
# 2022-11-18 00:45:20 base_stability_analyzer.py INFO    : Classifier 63 / 100 was tested
# 2022-11-18 00:45:20 base_stability_analyzer.py INFO    : Start testing of classifier 64 / 100
# 2022-11-18 00:45:29 base_stability_analyzer.py INFO    : Classifier 64 / 100 was tested
# 2022-11-18 00:45:29 base_stability_analyzer.py INFO    : Start testing of classifier 65 / 100
# 2022-11-18 00:45:38 base_stability_analyzer.py INFO    : Classifier 65 / 100 was tested
# 2022-11-18 00:45:38 base_stability_analyzer.py INFO    : Start testing of classifier 66 / 100
# 2022-11-18 00:45:46 base_stability_analyzer.py INFO    : Classifier 66 / 100 was tested
# 2022-11-18 00:45:46 base_stability_analyzer.py INFO    : Start testing of classifier 67 / 100
# 2022-11-18 00:45:55 base_stability_analyzer.py INFO    : Classifier 67 / 100 was tested
# 2022-11-18 00:45:55 base_stability_analyzer.py INFO    : Start testing of classifier 68 / 100
# 2022-11-18 00:46:04 base_stability_analyzer.py INFO    : Classifier 68 / 100 was tested
# 2022-11-18 00:46:04 base_stability_analyzer.py INFO    : Start testing of classifier 69 / 100
# 2022-11-18 00:46:13 base_stability_analyzer.py INFO    : Classifier 69 / 100 was tested
# 2022-11-18 00:46:13 base_stability_analyzer.py INFO    : Start testing of classifier 70 / 100
# 2022-11-18 00:46:21 base_stability_analyzer.py INFO    : Classifier 70 / 100 was tested
# 2022-11-18 00:46:21 base_stability_analyzer.py INFO    : Start testing of classifier 71 / 100
# 2022-11-18 00:46:31 base_stability_analyzer.py INFO    : Classifier 71 / 100 was tested
# 2022-11-18 00:46:31 base_stability_analyzer.py INFO    : Start testing of classifier 72 / 100
# 2022-11-18 00:46:39 base_stability_analyzer.py INFO    : Classifier 72 / 100 was tested
# 2022-11-18 00:46:39 base_stability_analyzer.py INFO    : Start testing of classifier 73 / 100
# 2022-11-18 00:46:46 base_stability_analyzer.py INFO    : Classifier 73 / 100 was tested
# 2022-11-18 00:46:46 base_stability_analyzer.py INFO    : Start testing of classifier 74 / 100
# 2022-11-18 00:46:54 base_stability_analyzer.py INFO    : Classifier 74 / 100 was tested
# 2022-11-18 00:46:54 base_stability_analyzer.py INFO    : Start testing of classifier 75 / 100
# 2022-11-18 00:47:02 base_stability_analyzer.py INFO    : Classifier 75 / 100 was tested
# 2022-11-18 00:47:02 base_stability_analyzer.py INFO    : Start testing of classifier 76 / 100
# 2022-11-18 00:47:11 base_stability_analyzer.py INFO    : Classifier 76 / 100 was tested
# 2022-11-18 00:47:11 base_stability_analyzer.py INFO    : Start testing of classifier 77 / 100
# 2022-11-18 00:47:19 base_stability_analyzer.py INFO    : Classifier 77 / 100 was tested
# 2022-11-18 00:47:19 base_stability_analyzer.py INFO    : Start testing of classifier 78 / 100
# 2022-11-18 00:47:28 base_stability_analyzer.py INFO    : Classifier 78 / 100 was tested
# 2022-11-18 00:47:28 base_stability_analyzer.py INFO    : Start testing of classifier 79 / 100
# 2022-11-18 00:47:36 base_stability_analyzer.py INFO    : Classifier 79 / 100 was tested
# 2022-11-18 00:47:36 base_stability_analyzer.py INFO    : Start testing of classifier 80 / 100
# 2022-11-18 00:47:46 base_stability_analyzer.py INFO    : Classifier 80 / 100 was tested
# 2022-11-18 00:47:46 base_stability_analyzer.py INFO    : Start testing of classifier 81 / 100
# 2022-11-18 00:47:55 base_stability_analyzer.py INFO    : Classifier 81 / 100 was tested
# 2022-11-18 00:47:55 base_stability_analyzer.py INFO    : Start testing of classifier 82 / 100
# 2022-11-18 00:48:04 base_stability_analyzer.py INFO    : Classifier 82 / 100 was tested
# 2022-11-18 00:48:04 base_stability_analyzer.py INFO    : Start testing of classifier 83 / 100
# 2022-11-18 00:48:12 base_stability_analyzer.py INFO    : Classifier 83 / 100 was tested
# 2022-11-18 00:48:12 base_stability_analyzer.py INFO    : Start testing of classifier 84 / 100
# 2022-11-18 00:48:20 base_stability_analyzer.py INFO    : Classifier 84 / 100 was tested
# 2022-11-18 00:48:20 base_stability_analyzer.py INFO    : Start testing of classifier 85 / 100
# 2022-11-18 00:48:29 base_stability_analyzer.py INFO    : Classifier 85 / 100 was tested
# 2022-11-18 00:48:29 base_stability_analyzer.py INFO    : Start testing of classifier 86 / 100
# 2022-11-18 00:48:37 base_stability_analyzer.py INFO    : Classifier 86 / 100 was tested
# 2022-11-18 00:48:37 base_stability_analyzer.py INFO    : Start testing of classifier 87 / 100
# 2022-11-18 00:48:45 base_stability_analyzer.py INFO    : Classifier 87 / 100 was tested
# 2022-11-18 00:48:45 base_stability_analyzer.py INFO    : Start testing of classifier 88 / 100
# 2022-11-18 00:48:54 base_stability_analyzer.py INFO    : Classifier 88 / 100 was tested
# 2022-11-18 00:48:54 base_stability_analyzer.py INFO    : Start testing of classifier 89 / 100
# 2022-11-18 00:49:03 base_stability_analyzer.py INFO    : Classifier 89 / 100 was tested
# 2022-11-18 00:49:03 base_stability_analyzer.py INFO    : Start testing of classifier 90 / 100
# 2022-11-18 00:49:12 base_stability_analyzer.py INFO    : Classifier 90 / 100 was tested
# 2022-11-18 00:49:12 base_stability_analyzer.py INFO    : Start testing of classifier 91 / 100
# 2022-11-18 00:49:22 base_stability_analyzer.py INFO    : Classifier 91 / 100 was tested
# 2022-11-18 00:49:22 base_stability_analyzer.py INFO    : Start testing of classifier 92 / 100
# 2022-11-18 00:49:31 base_stability_analyzer.py INFO    : Classifier 92 / 100 was tested
# 2022-11-18 00:49:31 base_stability_analyzer.py INFO    : Start testing of classifier 93 / 100
# 2022-11-18 00:49:39 base_stability_analyzer.py INFO    : Classifier 93 / 100 was tested
# 2022-11-18 00:49:39 base_stability_analyzer.py INFO    : Start testing of classifier 94 / 100
# 2022-11-18 00:49:47 base_stability_analyzer.py INFO    : Classifier 94 / 100 was tested
# 2022-11-18 00:49:47 base_stability_analyzer.py INFO    : Start testing of classifier 95 / 100
# 2022-11-18 00:49:55 base_stability_analyzer.py INFO    : Classifier 95 / 100 was tested
# 2022-11-18 00:49:55 base_stability_analyzer.py INFO    : Start testing of classifier 96 / 100
# 2022-11-18 00:50:04 base_stability_analyzer.py INFO    : Classifier 96 / 100 was tested
# 2022-11-18 00:50:04 base_stability_analyzer.py INFO    : Start testing of classifier 97 / 100
# 2022-11-18 00:50:12 base_stability_analyzer.py INFO    : Classifier 97 / 100 was tested
# 2022-11-18 00:50:12 base_stability_analyzer.py INFO    : Start testing of classifier 98 / 100
# 2022-11-18 00:50:20 base_stability_analyzer.py INFO    : Classifier 98 / 100 was tested
# 2022-11-18 00:50:20 base_stability_analyzer.py INFO    : Start testing of classifier 99 / 100
# 2022-11-18 00:50:29 base_stability_analyzer.py INFO    : Classifier 99 / 100 was tested
# 2022-11-18 00:50:29 base_stability_analyzer.py INFO    : Start testing of classifier 100 / 100
# 2022-11-18 00:50:37 base_stability_analyzer.py INFO    : Classifier 100 / 100 was tested
# General Ensemble Accuracy: 0.8148
# Mean: 0.4434
# Std: 0.0681
# IQR: 0.0521
# Per sample accuracy: 0.8105
# Label stability: 0.9339
# Jitter: 0.048
