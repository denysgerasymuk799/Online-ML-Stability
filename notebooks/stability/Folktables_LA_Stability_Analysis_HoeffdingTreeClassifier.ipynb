# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
import pandas as pd
import seaborn as sns

from river import compose
from river import preprocessing
from river import tree
from sklearn.model_selection import train_test_split

from source.config import *
from source.stability.incremental_stability_analyzer import IncrementalStabilityAnalyzer
from source.utils.incremental_model_utils import train_incremental_model
from source.data_loaders.folktables_dataset_from_pd import FolktablesDatasetFromPandas

# %%
sns.set(rc={'figure.figsize':(15, 5)})
dataset_name = 'folktables'
dataset_config = DATASETS_CONFIG[dataset_name]
TARGET_COLUMN = dataset_config['target_column']

# %%
# Creating a data frame
df = pd.read_csv("../../datasets/folktables-LA-2018.csv", delimiter=',')
df.head()
# Out:
#    AGEP  SCHL  MAR  RELP  DIS  ESP  CIT  MIG  MIL  ANC  NATIVITY  DEAR  DEYE  \
# 0    29    18    5    16    2    0    1    1    4    2         1     2     2
# 1    17    13    5    16    2    0    1    1    4    1         1     2     2
# 2    37    13    5    16    2    0    1    1    4    1         1     2     2
# 3    86    12    2    16    1    0    1    1    4    1         1     2     1
# 4    22    19    5    17    2    0    1    1    4    1         1     2     2
#
#    DREM  SEX  RAC1P  ESR
# 0     2    1      1    0
# 1     2    1      2    0
# 2     2    1      1    0
# 3     2    2      2    0
# 4     2    2      1    0

# %%
df.shape
# Out:
# (43588, 17)

# %%
df.columns
# Out:
# Index(['AGEP', 'SCHL', 'MAR', 'RELP', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
#        'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'SEX', 'RAC1P', 'ESR'],
#       dtype='object')

# %%
df['ESR'].value_counts()
# Out:
# 0    25363
# 1    18225
# Name: ESR, dtype: int64

# %%
dataset_size = df.shape[0]
test_size = int(TEST_FRACTION * dataset_size)
validation_size = test_size

train_cv_df, test_df = train_test_split(df, test_size=test_size, random_state=SEED)
train_df, cv_df = train_test_split(train_cv_df, test_size=validation_size, random_state=SEED)
print("train_df shape: ", train_df.shape)
print("cv_df shape: ", cv_df.shape)
print("test_df shape: ", test_df.shape)
# Out:
# train_df shape:  (26154, 17)
# cv_df shape:  (8717, 17)
# test_df shape:  (8717, 17)

# %%
train_dataset = FolktablesDatasetFromPandas(pd_dataset=train_df)

# %%
numerical_features = dataset_config['numerical_features']
categorical_features = [feature for feature in df.columns if feature not in numerical_features + [TARGET_COLUMN]]

categorical_features
# Out:
# ['MAR',
#  'RELP',
#  'DIS',
#  'ESP',
#  'CIT',
#  'MIG',
#  'MIL',
#  'ANC',
#  'NATIVITY',
#  'DEAR',
#  'DEYE',
#  'DREM',
#  'SEX',
#  'RAC1P']

# %% [markdown]
# ### Apply data transformations

# %%
def get_transform_pipeline(categorical_features, numerical_features):
    transform_pipeline = compose.Select(categorical_features[0])
    for feature in categorical_features[1:]:
        transform_pipeline += compose.Select(feature)
    transform_pipeline |= preprocessing.OneHotEncoder()

    for feature in numerical_features:
        transform_pipeline += compose.Select(feature)
    transform_pipeline |= preprocessing.MinMaxScaler()

    return transform_pipeline

# %%
transform_pipeline = get_transform_pipeline(categorical_features, numerical_features)

for idx, (x, y) in enumerate(train_dataset):
    print(f'Initial features: {x}\n')
    x = transform_pipeline.transform_one(x)
    print(f'Transformed features: {x}\n\n')
    if idx + 1 == 10:
        break
# Out:
# Initial features: {'AGEP': 93, 'SCHL': 19, 'MAR': '3', 'RELP': '0', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '4', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '1', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 58, 'SCHL': 23, 'MAR': '3', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 1.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'DIS_2': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 69, 'SCHL': 17, 'MAR': '3', 'RELP': '0', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.3142857142857143, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 1.0, 'DIS_2': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 28, 'SCHL': 22, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '4', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.8333333333333334, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 1.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'DIS_2': 1.0, 'RELP_0': 0.0, 'MAR_1': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 35, 'SCHL': 16, 'MAR': '5', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '2'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.1076923076923077, 'RAC1P_1': 0.0, 'RAC1P_2': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_1': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_1': 1.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'DIS_2': 1.0, 'RELP_0': 0.0, 'MAR_5': 0.0, 'MAR_1': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 66, 'SCHL': 16, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.5846153846153846, 'RAC1P_1': 1.0, 'RAC1P_2': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_1': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_1': 1.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'DIS_2': 1.0, 'RELP_0': 0.0, 'MAR_5': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 41, 'SCHL': 18, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.2857142857142857, 'AGEP': 0.2, 'RAC1P_1': 1.0, 'RAC1P_2': 0.0, 'SEX_1': 1.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_1': 0.0, 'ANC_2': 1.0, 'MIL_4': 0.0, 'MIG_1': 1.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'DIS_2': 1.0, 'RELP_0': 0.0, 'MAR_5': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 15, 'SCHL': 11, 'MAR': '5', 'RELP': '2', 'DIS': '1', 'ESP': '2', 'CIT': '1', 'MIG': '1', 'MIL': '0', 'ANC': '3', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '1', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_1': 1.0, 'RAC1P_2': 0.0, 'SEX_1': 1.0, 'SEX_2': 0.0, 'DREM_1': 0.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_1': 0.0, 'ANC_2': 0.0, 'ANC_3': 0.0, 'MIL_4': 0.0, 'MIL_0': 0.0, 'MIG_1': 1.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'ESP_2': 0.0, 'DIS_1': 1.0, 'DIS_2': 0.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'MAR_5': 1.0, 'MAR_1': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 51, 'SCHL': 16, 'MAR': '1', 'RELP': '1', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '2'}
#
# Transformed features: {'SCHL': 0.4166666666666667, 'AGEP': 0.46153846153846156, 'RAC1P_1': 0.0, 'RAC1P_2': 1.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_1': 0.0, 'DREM_2': 1.0, 'DEYE_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_1': 1.0, 'ANC_2': 0.0, 'ANC_3': 0.0, 'MIL_4': 1.0, 'MIL_0': 0.0, 'MIG_1': 1.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 1.0, 'ESP_2': 0.0, 'DIS_1': 0.0, 'DIS_2': 1.0, 'RELP_1': 0.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'MAR_5': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 73, 'SCHL': 15, 'MAR': '1', 'RELP': '1', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '1', 'DREM': '1', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.3333333333333333, 'AGEP': 0.7435897435897436, 'RAC1P_1': 1.0, 'RAC1P_2': 0.0, 'SEX_1': 0.0, 'SEX_2': 1.0, 'DREM_1': 1.0, 'DREM_2': 0.0, 'DEYE_1': 1.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'ANC_1': 1.0, 'ANC_2': 0.0, 'ANC_3': 0.0, 'MIL_4': 1.0, 'MIL_0': 0.0, 'MIG_1': 1.0, 'MIG_3': 0.0, 'CIT_1': 0.0, 'ESP_0': 1.0, 'ESP_2': 0.0, 'DIS_1': 1.0, 'DIS_2': 0.0, 'RELP_1': 0.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'MAR_5': 0.0, 'MAR_1': 1.0, 'MAR_3': 0.0}

# %% [markdown]
# ### Analyze stability of Adaptive Random Forest classifier

# %%
def get_base_model():
    return tree.HoeffdingTreeClassifier(grace_period=50, delta=0.01), 'HoeffdingTreeClassifier'

# %%
base_model, base_model_name = get_base_model()

# Conduct model training
base_model = train_incremental_model(base_model, train_dataset, train_df.shape[0])
# Out:
# 2022-11-29 12:29:18 incremental_model_utils.py INFO    : Iteration 1000/26154 -- Accuracy: 72.37%; WeightedF1: 72.52%
# 2022-11-29 12:29:18 incremental_model_utils.py INFO    : Iteration 2000/26154 -- Accuracy: 74.64%; WeightedF1: 74.75%
# 2022-11-29 12:29:18 incremental_model_utils.py INFO    : Iteration 3000/26154 -- Accuracy: 75.59%; WeightedF1: 75.72%
# 2022-11-29 12:29:18 incremental_model_utils.py INFO    : Iteration 4000/26154 -- Accuracy: 75.79%; WeightedF1: 75.94%
# 2022-11-29 12:29:18 incremental_model_utils.py INFO    : Iteration 5000/26154 -- Accuracy: 76.70%; WeightedF1: 76.82%
# 2022-11-29 12:29:18 incremental_model_utils.py INFO    : Iteration 6000/26154 -- Accuracy: 76.16%; WeightedF1: 76.29%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 7000/26154 -- Accuracy: 76.50%; WeightedF1: 76.63%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 8000/26154 -- Accuracy: 76.67%; WeightedF1: 76.81%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 9000/26154 -- Accuracy: 76.90%; WeightedF1: 77.05%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 10000/26154 -- Accuracy: 77.09%; WeightedF1: 77.22%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 11000/26154 -- Accuracy: 77.24%; WeightedF1: 77.37%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 12000/26154 -- Accuracy: 77.35%; WeightedF1: 77.48%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 13000/26154 -- Accuracy: 77.47%; WeightedF1: 77.59%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 14000/26154 -- Accuracy: 77.62%; WeightedF1: 77.75%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 15000/26154 -- Accuracy: 77.69%; WeightedF1: 77.81%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 16000/26154 -- Accuracy: 77.84%; WeightedF1: 77.96%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 17000/26154 -- Accuracy: 78.06%; WeightedF1: 78.18%
# 2022-11-29 12:29:19 incremental_model_utils.py INFO    : Iteration 18000/26154 -- Accuracy: 78.16%; WeightedF1: 78.28%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 19000/26154 -- Accuracy: 78.22%; WeightedF1: 78.34%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 20000/26154 -- Accuracy: 78.37%; WeightedF1: 78.49%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 21000/26154 -- Accuracy: 78.36%; WeightedF1: 78.48%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 22000/26154 -- Accuracy: 78.40%; WeightedF1: 78.52%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 23000/26154 -- Accuracy: 78.53%; WeightedF1: 78.65%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 24000/26154 -- Accuracy: 78.56%; WeightedF1: 78.68%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 25000/26154 -- Accuracy: 78.68%; WeightedF1: 78.81%
# 2022-11-29 12:29:20 incremental_model_utils.py INFO    : Iteration 26000/26154 -- Accuracy: 78.70%; WeightedF1: 78.82%
# Metrics after incremental model training:
# Accuracy: 78.71%
# WeightedF1: 78.83%

# %%
stability_analyzer = IncrementalStabilityAnalyzer(base_model,
                                                  base_model_name=base_model_name,
                                                  train_pd_dataset=cv_df,
                                                  test_pd_dataset=test_df,
                                                  test_y_true=test_df[TARGET_COLUMN],
                                                  dataset_reader=FolktablesDatasetFromPandas,
                                                  dataset_name=dataset_name + '_LA',
                                                  n_estimators=200)

# %%
stability_analyzer.measure_stability_metrics(make_plots=True)
# Out:
# 2022-11-29 12:29:34 base_stability_analyzer.py INFO    : Start testing of classifier 1 / 200
# 2022-11-29 12:29:35 base_stability_analyzer.py INFO    : Classifier 1 / 200 was tested
# 2022-11-29 12:29:35 base_stability_analyzer.py INFO    : Start testing of classifier 2 / 200
# 2022-11-29 12:29:35 base_stability_analyzer.py INFO    : Classifier 2 / 200 was tested
# 2022-11-29 12:29:35 base_stability_analyzer.py INFO    : Start testing of classifier 3 / 200
# 2022-11-29 12:29:36 base_stability_analyzer.py INFO    : Classifier 3 / 200 was tested
# 2022-11-29 12:29:36 base_stability_analyzer.py INFO    : Start testing of classifier 4 / 200
# 2022-11-29 12:29:37 base_stability_analyzer.py INFO    : Classifier 4 / 200 was tested
# 2022-11-29 12:29:37 base_stability_analyzer.py INFO    : Start testing of classifier 5 / 200
# 2022-11-29 12:29:37 base_stability_analyzer.py INFO    : Classifier 5 / 200 was tested
# 2022-11-29 12:29:37 base_stability_analyzer.py INFO    : Start testing of classifier 6 / 200
# 2022-11-29 12:29:38 base_stability_analyzer.py INFO    : Classifier 6 / 200 was tested
# 2022-11-29 12:29:38 base_stability_analyzer.py INFO    : Start testing of classifier 7 / 200
# 2022-11-29 12:29:38 base_stability_analyzer.py INFO    : Classifier 7 / 200 was tested
# 2022-11-29 12:29:38 base_stability_analyzer.py INFO    : Start testing of classifier 8 / 200
# 2022-11-29 12:29:39 base_stability_analyzer.py INFO    : Classifier 8 / 200 was tested
# 2022-11-29 12:29:39 base_stability_analyzer.py INFO    : Start testing of classifier 9 / 200
# 2022-11-29 12:29:39 base_stability_analyzer.py INFO    : Classifier 9 / 200 was tested
# 2022-11-29 12:29:39 base_stability_analyzer.py INFO    : Start testing of classifier 10 / 200
# 2022-11-29 12:29:40 base_stability_analyzer.py INFO    : Classifier 10 / 200 was tested
# 2022-11-29 12:29:40 base_stability_analyzer.py INFO    : Start testing of classifier 11 / 200
# 2022-11-29 12:29:40 base_stability_analyzer.py INFO    : Classifier 11 / 200 was tested
# 2022-11-29 12:29:40 base_stability_analyzer.py INFO    : Start testing of classifier 12 / 200
# 2022-11-29 12:29:41 base_stability_analyzer.py INFO    : Classifier 12 / 200 was tested
# 2022-11-29 12:29:41 base_stability_analyzer.py INFO    : Start testing of classifier 13 / 200
# 2022-11-29 12:29:41 base_stability_analyzer.py INFO    : Classifier 13 / 200 was tested
# 2022-11-29 12:29:41 base_stability_analyzer.py INFO    : Start testing of classifier 14 / 200
# 2022-11-29 12:29:42 base_stability_analyzer.py INFO    : Classifier 14 / 200 was tested
# 2022-11-29 12:29:42 base_stability_analyzer.py INFO    : Start testing of classifier 15 / 200
# 2022-11-29 12:29:42 base_stability_analyzer.py INFO    : Classifier 15 / 200 was tested
# 2022-11-29 12:29:42 base_stability_analyzer.py INFO    : Start testing of classifier 16 / 200
# 2022-11-29 12:29:43 base_stability_analyzer.py INFO    : Classifier 16 / 200 was tested
# 2022-11-29 12:29:43 base_stability_analyzer.py INFO    : Start testing of classifier 17 / 200
# 2022-11-29 12:29:43 base_stability_analyzer.py INFO    : Classifier 17 / 200 was tested
# 2022-11-29 12:29:43 base_stability_analyzer.py INFO    : Start testing of classifier 18 / 200
# 2022-11-29 12:29:44 base_stability_analyzer.py INFO    : Classifier 18 / 200 was tested
# 2022-11-29 12:29:44 base_stability_analyzer.py INFO    : Start testing of classifier 19 / 200
# 2022-11-29 12:29:44 base_stability_analyzer.py INFO    : Classifier 19 / 200 was tested
# 2022-11-29 12:29:44 base_stability_analyzer.py INFO    : Start testing of classifier 20 / 200
# 2022-11-29 12:29:45 base_stability_analyzer.py INFO    : Classifier 20 / 200 was tested
# 2022-11-29 12:29:45 base_stability_analyzer.py INFO    : Start testing of classifier 21 / 200
# 2022-11-29 12:29:45 base_stability_analyzer.py INFO    : Classifier 21 / 200 was tested
# 2022-11-29 12:29:45 base_stability_analyzer.py INFO    : Start testing of classifier 22 / 200
# 2022-11-29 12:29:46 base_stability_analyzer.py INFO    : Classifier 22 / 200 was tested
# 2022-11-29 12:29:46 base_stability_analyzer.py INFO    : Start testing of classifier 23 / 200
# 2022-11-29 12:29:47 base_stability_analyzer.py INFO    : Classifier 23 / 200 was tested
# 2022-11-29 12:29:47 base_stability_analyzer.py INFO    : Start testing of classifier 24 / 200
# 2022-11-29 12:29:47 base_stability_analyzer.py INFO    : Classifier 24 / 200 was tested
# 2022-11-29 12:29:47 base_stability_analyzer.py INFO    : Start testing of classifier 25 / 200
# 2022-11-29 12:29:48 base_stability_analyzer.py INFO    : Classifier 25 / 200 was tested
# 2022-11-29 12:29:48 base_stability_analyzer.py INFO    : Start testing of classifier 26 / 200
# 2022-11-29 12:29:48 base_stability_analyzer.py INFO    : Classifier 26 / 200 was tested
# 2022-11-29 12:29:48 base_stability_analyzer.py INFO    : Start testing of classifier 27 / 200
# 2022-11-29 12:29:49 base_stability_analyzer.py INFO    : Classifier 27 / 200 was tested
# 2022-11-29 12:29:49 base_stability_analyzer.py INFO    : Start testing of classifier 28 / 200
# 2022-11-29 12:29:49 base_stability_analyzer.py INFO    : Classifier 28 / 200 was tested
# 2022-11-29 12:29:49 base_stability_analyzer.py INFO    : Start testing of classifier 29 / 200
# 2022-11-29 12:29:50 base_stability_analyzer.py INFO    : Classifier 29 / 200 was tested
# 2022-11-29 12:29:50 base_stability_analyzer.py INFO    : Start testing of classifier 30 / 200
# 2022-11-29 12:29:50 base_stability_analyzer.py INFO    : Classifier 30 / 200 was tested
# 2022-11-29 12:29:50 base_stability_analyzer.py INFO    : Start testing of classifier 31 / 200
# 2022-11-29 12:29:51 base_stability_analyzer.py INFO    : Classifier 31 / 200 was tested
# 2022-11-29 12:29:51 base_stability_analyzer.py INFO    : Start testing of classifier 32 / 200
# 2022-11-29 12:29:51 base_stability_analyzer.py INFO    : Classifier 32 / 200 was tested
# 2022-11-29 12:29:51 base_stability_analyzer.py INFO    : Start testing of classifier 33 / 200
# 2022-11-29 12:29:52 base_stability_analyzer.py INFO    : Classifier 33 / 200 was tested
# 2022-11-29 12:29:52 base_stability_analyzer.py INFO    : Start testing of classifier 34 / 200
# 2022-11-29 12:29:52 base_stability_analyzer.py INFO    : Classifier 34 / 200 was tested
# 2022-11-29 12:29:52 base_stability_analyzer.py INFO    : Start testing of classifier 35 / 200
# 2022-11-29 12:29:53 base_stability_analyzer.py INFO    : Classifier 35 / 200 was tested
# 2022-11-29 12:29:53 base_stability_analyzer.py INFO    : Start testing of classifier 36 / 200
# 2022-11-29 12:29:54 base_stability_analyzer.py INFO    : Classifier 36 / 200 was tested
# 2022-11-29 12:29:54 base_stability_analyzer.py INFO    : Start testing of classifier 37 / 200
# 2022-11-29 12:29:54 base_stability_analyzer.py INFO    : Classifier 37 / 200 was tested
# 2022-11-29 12:29:54 base_stability_analyzer.py INFO    : Start testing of classifier 38 / 200
# 2022-11-29 12:29:55 base_stability_analyzer.py INFO    : Classifier 38 / 200 was tested
# 2022-11-29 12:29:55 base_stability_analyzer.py INFO    : Start testing of classifier 39 / 200
# 2022-11-29 12:29:56 base_stability_analyzer.py INFO    : Classifier 39 / 200 was tested
# 2022-11-29 12:29:56 base_stability_analyzer.py INFO    : Start testing of classifier 40 / 200
# 2022-11-29 12:29:56 base_stability_analyzer.py INFO    : Classifier 40 / 200 was tested
# 2022-11-29 12:29:56 base_stability_analyzer.py INFO    : Start testing of classifier 41 / 200
# 2022-11-29 12:29:57 base_stability_analyzer.py INFO    : Classifier 41 / 200 was tested
# 2022-11-29 12:29:57 base_stability_analyzer.py INFO    : Start testing of classifier 42 / 200
# 2022-11-29 12:29:58 base_stability_analyzer.py INFO    : Classifier 42 / 200 was tested
# 2022-11-29 12:29:58 base_stability_analyzer.py INFO    : Start testing of classifier 43 / 200
# 2022-11-29 12:29:58 base_stability_analyzer.py INFO    : Classifier 43 / 200 was tested
# 2022-11-29 12:29:58 base_stability_analyzer.py INFO    : Start testing of classifier 44 / 200
# 2022-11-29 12:29:59 base_stability_analyzer.py INFO    : Classifier 44 / 200 was tested
# 2022-11-29 12:29:59 base_stability_analyzer.py INFO    : Start testing of classifier 45 / 200
# 2022-11-29 12:29:59 base_stability_analyzer.py INFO    : Classifier 45 / 200 was tested
# 2022-11-29 12:29:59 base_stability_analyzer.py INFO    : Start testing of classifier 46 / 200
# 2022-11-29 12:30:00 base_stability_analyzer.py INFO    : Classifier 46 / 200 was tested
# 2022-11-29 12:30:00 base_stability_analyzer.py INFO    : Start testing of classifier 47 / 200
# 2022-11-29 12:30:01 base_stability_analyzer.py INFO    : Classifier 47 / 200 was tested
# 2022-11-29 12:30:01 base_stability_analyzer.py INFO    : Start testing of classifier 48 / 200
# 2022-11-29 12:30:01 base_stability_analyzer.py INFO    : Classifier 48 / 200 was tested
# 2022-11-29 12:30:01 base_stability_analyzer.py INFO    : Start testing of classifier 49 / 200
# 2022-11-29 12:30:02 base_stability_analyzer.py INFO    : Classifier 49 / 200 was tested
# 2022-11-29 12:30:02 base_stability_analyzer.py INFO    : Start testing of classifier 50 / 200
# 2022-11-29 12:30:02 base_stability_analyzer.py INFO    : Classifier 50 / 200 was tested
# 2022-11-29 12:30:02 base_stability_analyzer.py INFO    : Start testing of classifier 51 / 200
# 2022-11-29 12:30:03 base_stability_analyzer.py INFO    : Classifier 51 / 200 was tested
# 2022-11-29 12:30:03 base_stability_analyzer.py INFO    : Start testing of classifier 52 / 200
# 2022-11-29 12:30:04 base_stability_analyzer.py INFO    : Classifier 52 / 200 was tested
# 2022-11-29 12:30:04 base_stability_analyzer.py INFO    : Start testing of classifier 53 / 200
# 2022-11-29 12:30:04 base_stability_analyzer.py INFO    : Classifier 53 / 200 was tested
# 2022-11-29 12:30:04 base_stability_analyzer.py INFO    : Start testing of classifier 54 / 200
# 2022-11-29 12:30:05 base_stability_analyzer.py INFO    : Classifier 54 / 200 was tested
# 2022-11-29 12:30:05 base_stability_analyzer.py INFO    : Start testing of classifier 55 / 200
# 2022-11-29 12:30:06 base_stability_analyzer.py INFO    : Classifier 55 / 200 was tested
# 2022-11-29 12:30:06 base_stability_analyzer.py INFO    : Start testing of classifier 56 / 200
# 2022-11-29 12:30:07 base_stability_analyzer.py INFO    : Classifier 56 / 200 was tested
# 2022-11-29 12:30:07 base_stability_analyzer.py INFO    : Start testing of classifier 57 / 200
# 2022-11-29 12:30:08 base_stability_analyzer.py INFO    : Classifier 57 / 200 was tested
# 2022-11-29 12:30:08 base_stability_analyzer.py INFO    : Start testing of classifier 58 / 200
# 2022-11-29 12:30:09 base_stability_analyzer.py INFO    : Classifier 58 / 200 was tested
# 2022-11-29 12:30:09 base_stability_analyzer.py INFO    : Start testing of classifier 59 / 200
# 2022-11-29 12:30:09 base_stability_analyzer.py INFO    : Classifier 59 / 200 was tested
# 2022-11-29 12:30:09 base_stability_analyzer.py INFO    : Start testing of classifier 60 / 200
# 2022-11-29 12:30:10 base_stability_analyzer.py INFO    : Classifier 60 / 200 was tested
# 2022-11-29 12:30:10 base_stability_analyzer.py INFO    : Start testing of classifier 61 / 200
# 2022-11-29 12:30:11 base_stability_analyzer.py INFO    : Classifier 61 / 200 was tested
# 2022-11-29 12:30:11 base_stability_analyzer.py INFO    : Start testing of classifier 62 / 200
# 2022-11-29 12:30:11 base_stability_analyzer.py INFO    : Classifier 62 / 200 was tested
# 2022-11-29 12:30:11 base_stability_analyzer.py INFO    : Start testing of classifier 63 / 200
# 2022-11-29 12:30:12 base_stability_analyzer.py INFO    : Classifier 63 / 200 was tested
# 2022-11-29 12:30:12 base_stability_analyzer.py INFO    : Start testing of classifier 64 / 200
# 2022-11-29 12:30:13 base_stability_analyzer.py INFO    : Classifier 64 / 200 was tested
# 2022-11-29 12:30:13 base_stability_analyzer.py INFO    : Start testing of classifier 65 / 200
# 2022-11-29 12:30:13 base_stability_analyzer.py INFO    : Classifier 65 / 200 was tested
# 2022-11-29 12:30:13 base_stability_analyzer.py INFO    : Start testing of classifier 66 / 200
# 2022-11-29 12:30:14 base_stability_analyzer.py INFO    : Classifier 66 / 200 was tested
# 2022-11-29 12:30:14 base_stability_analyzer.py INFO    : Start testing of classifier 67 / 200
# 2022-11-29 12:30:15 base_stability_analyzer.py INFO    : Classifier 67 / 200 was tested
# 2022-11-29 12:30:15 base_stability_analyzer.py INFO    : Start testing of classifier 68 / 200
# 2022-11-29 12:30:15 base_stability_analyzer.py INFO    : Classifier 68 / 200 was tested
# 2022-11-29 12:30:15 base_stability_analyzer.py INFO    : Start testing of classifier 69 / 200
# 2022-11-29 12:30:16 base_stability_analyzer.py INFO    : Classifier 69 / 200 was tested
# 2022-11-29 12:30:16 base_stability_analyzer.py INFO    : Start testing of classifier 70 / 200
# 2022-11-29 12:30:16 base_stability_analyzer.py INFO    : Classifier 70 / 200 was tested
# 2022-11-29 12:30:16 base_stability_analyzer.py INFO    : Start testing of classifier 71 / 200
# 2022-11-29 12:30:17 base_stability_analyzer.py INFO    : Classifier 71 / 200 was tested
# 2022-11-29 12:30:17 base_stability_analyzer.py INFO    : Start testing of classifier 72 / 200
# 2022-11-29 12:30:18 base_stability_analyzer.py INFO    : Classifier 72 / 200 was tested
# 2022-11-29 12:30:18 base_stability_analyzer.py INFO    : Start testing of classifier 73 / 200
# 2022-11-29 12:30:18 base_stability_analyzer.py INFO    : Classifier 73 / 200 was tested
# 2022-11-29 12:30:18 base_stability_analyzer.py INFO    : Start testing of classifier 74 / 200
# 2022-11-29 12:30:19 base_stability_analyzer.py INFO    : Classifier 74 / 200 was tested
# 2022-11-29 12:30:19 base_stability_analyzer.py INFO    : Start testing of classifier 75 / 200
# 2022-11-29 12:30:20 base_stability_analyzer.py INFO    : Classifier 75 / 200 was tested
# 2022-11-29 12:30:20 base_stability_analyzer.py INFO    : Start testing of classifier 76 / 200
# 2022-11-29 12:30:20 base_stability_analyzer.py INFO    : Classifier 76 / 200 was tested
# 2022-11-29 12:30:20 base_stability_analyzer.py INFO    : Start testing of classifier 77 / 200
# 2022-11-29 12:30:21 base_stability_analyzer.py INFO    : Classifier 77 / 200 was tested
# 2022-11-29 12:30:21 base_stability_analyzer.py INFO    : Start testing of classifier 78 / 200
# 2022-11-29 12:30:22 base_stability_analyzer.py INFO    : Classifier 78 / 200 was tested
# 2022-11-29 12:30:22 base_stability_analyzer.py INFO    : Start testing of classifier 79 / 200
# 2022-11-29 12:30:22 base_stability_analyzer.py INFO    : Classifier 79 / 200 was tested
# 2022-11-29 12:30:22 base_stability_analyzer.py INFO    : Start testing of classifier 80 / 200
# 2022-11-29 12:30:23 base_stability_analyzer.py INFO    : Classifier 80 / 200 was tested
# 2022-11-29 12:30:23 base_stability_analyzer.py INFO    : Start testing of classifier 81 / 200
# 2022-11-29 12:30:24 base_stability_analyzer.py INFO    : Classifier 81 / 200 was tested
# 2022-11-29 12:30:24 base_stability_analyzer.py INFO    : Start testing of classifier 82 / 200
# 2022-11-29 12:30:25 base_stability_analyzer.py INFO    : Classifier 82 / 200 was tested
# 2022-11-29 12:30:25 base_stability_analyzer.py INFO    : Start testing of classifier 83 / 200
# 2022-11-29 12:30:26 base_stability_analyzer.py INFO    : Classifier 83 / 200 was tested
# 2022-11-29 12:30:26 base_stability_analyzer.py INFO    : Start testing of classifier 84 / 200
# 2022-11-29 12:30:26 base_stability_analyzer.py INFO    : Classifier 84 / 200 was tested
# 2022-11-29 12:30:26 base_stability_analyzer.py INFO    : Start testing of classifier 85 / 200
# 2022-11-29 12:30:27 base_stability_analyzer.py INFO    : Classifier 85 / 200 was tested
# 2022-11-29 12:30:27 base_stability_analyzer.py INFO    : Start testing of classifier 86 / 200
# 2022-11-29 12:30:28 base_stability_analyzer.py INFO    : Classifier 86 / 200 was tested
# 2022-11-29 12:30:28 base_stability_analyzer.py INFO    : Start testing of classifier 87 / 200
# 2022-11-29 12:30:29 base_stability_analyzer.py INFO    : Classifier 87 / 200 was tested
# 2022-11-29 12:30:29 base_stability_analyzer.py INFO    : Start testing of classifier 88 / 200
# 2022-11-29 12:30:30 base_stability_analyzer.py INFO    : Classifier 88 / 200 was tested
# 2022-11-29 12:30:30 base_stability_analyzer.py INFO    : Start testing of classifier 89 / 200
# 2022-11-29 12:30:31 base_stability_analyzer.py INFO    : Classifier 89 / 200 was tested
# 2022-11-29 12:30:31 base_stability_analyzer.py INFO    : Start testing of classifier 90 / 200
# 2022-11-29 12:30:32 base_stability_analyzer.py INFO    : Classifier 90 / 200 was tested
# 2022-11-29 12:30:32 base_stability_analyzer.py INFO    : Start testing of classifier 91 / 200
# 2022-11-29 12:30:33 base_stability_analyzer.py INFO    : Classifier 91 / 200 was tested
# 2022-11-29 12:30:33 base_stability_analyzer.py INFO    : Start testing of classifier 92 / 200
# 2022-11-29 12:30:34 base_stability_analyzer.py INFO    : Classifier 92 / 200 was tested
# 2022-11-29 12:30:34 base_stability_analyzer.py INFO    : Start testing of classifier 93 / 200
# 2022-11-29 12:30:36 base_stability_analyzer.py INFO    : Classifier 93 / 200 was tested
# 2022-11-29 12:30:36 base_stability_analyzer.py INFO    : Start testing of classifier 94 / 200
# 2022-11-29 12:30:37 base_stability_analyzer.py INFO    : Classifier 94 / 200 was tested
# 2022-11-29 12:30:37 base_stability_analyzer.py INFO    : Start testing of classifier 95 / 200
# 2022-11-29 12:30:38 base_stability_analyzer.py INFO    : Classifier 95 / 200 was tested
# 2022-11-29 12:30:38 base_stability_analyzer.py INFO    : Start testing of classifier 96 / 200
# 2022-11-29 12:30:39 base_stability_analyzer.py INFO    : Classifier 96 / 200 was tested
# 2022-11-29 12:30:39 base_stability_analyzer.py INFO    : Start testing of classifier 97 / 200
# 2022-11-29 12:30:40 base_stability_analyzer.py INFO    : Classifier 97 / 200 was tested
# 2022-11-29 12:30:40 base_stability_analyzer.py INFO    : Start testing of classifier 98 / 200
# 2022-11-29 12:30:40 base_stability_analyzer.py INFO    : Classifier 98 / 200 was tested
# 2022-11-29 12:30:40 base_stability_analyzer.py INFO    : Start testing of classifier 99 / 200
# 2022-11-29 12:30:41 base_stability_analyzer.py INFO    : Classifier 99 / 200 was tested
# 2022-11-29 12:30:41 base_stability_analyzer.py INFO    : Start testing of classifier 100 / 200
# 2022-11-29 12:30:42 base_stability_analyzer.py INFO    : Classifier 100 / 200 was tested
# 2022-11-29 12:30:42 base_stability_analyzer.py INFO    : Start testing of classifier 101 / 200
# 2022-11-29 12:30:43 base_stability_analyzer.py INFO    : Classifier 101 / 200 was tested
# 2022-11-29 12:30:43 base_stability_analyzer.py INFO    : Start testing of classifier 102 / 200
# 2022-11-29 12:30:44 base_stability_analyzer.py INFO    : Classifier 102 / 200 was tested
# 2022-11-29 12:30:44 base_stability_analyzer.py INFO    : Start testing of classifier 103 / 200
# 2022-11-29 12:30:45 base_stability_analyzer.py INFO    : Classifier 103 / 200 was tested
# 2022-11-29 12:30:45 base_stability_analyzer.py INFO    : Start testing of classifier 104 / 200
# 2022-11-29 12:30:46 base_stability_analyzer.py INFO    : Classifier 104 / 200 was tested
# 2022-11-29 12:30:46 base_stability_analyzer.py INFO    : Start testing of classifier 105 / 200
# 2022-11-29 12:30:46 base_stability_analyzer.py INFO    : Classifier 105 / 200 was tested
# 2022-11-29 12:30:46 base_stability_analyzer.py INFO    : Start testing of classifier 106 / 200
# 2022-11-29 12:30:47 base_stability_analyzer.py INFO    : Classifier 106 / 200 was tested
# 2022-11-29 12:30:47 base_stability_analyzer.py INFO    : Start testing of classifier 107 / 200
# 2022-11-29 12:30:48 base_stability_analyzer.py INFO    : Classifier 107 / 200 was tested
# 2022-11-29 12:30:48 base_stability_analyzer.py INFO    : Start testing of classifier 108 / 200
# 2022-11-29 12:30:48 base_stability_analyzer.py INFO    : Classifier 108 / 200 was tested
# 2022-11-29 12:30:48 base_stability_analyzer.py INFO    : Start testing of classifier 109 / 200
# 2022-11-29 12:30:49 base_stability_analyzer.py INFO    : Classifier 109 / 200 was tested
# 2022-11-29 12:30:49 base_stability_analyzer.py INFO    : Start testing of classifier 110 / 200
# 2022-11-29 12:30:49 base_stability_analyzer.py INFO    : Classifier 110 / 200 was tested
# 2022-11-29 12:30:49 base_stability_analyzer.py INFO    : Start testing of classifier 111 / 200
# 2022-11-29 12:30:50 base_stability_analyzer.py INFO    : Classifier 111 / 200 was tested
# 2022-11-29 12:30:50 base_stability_analyzer.py INFO    : Start testing of classifier 112 / 200
# 2022-11-29 12:30:51 base_stability_analyzer.py INFO    : Classifier 112 / 200 was tested
# 2022-11-29 12:30:51 base_stability_analyzer.py INFO    : Start testing of classifier 113 / 200
# 2022-11-29 12:30:52 base_stability_analyzer.py INFO    : Classifier 113 / 200 was tested
# 2022-11-29 12:30:52 base_stability_analyzer.py INFO    : Start testing of classifier 114 / 200
# 2022-11-29 12:30:52 base_stability_analyzer.py INFO    : Classifier 114 / 200 was tested
# 2022-11-29 12:30:52 base_stability_analyzer.py INFO    : Start testing of classifier 115 / 200
# 2022-11-29 12:30:53 base_stability_analyzer.py INFO    : Classifier 115 / 200 was tested
# 2022-11-29 12:30:53 base_stability_analyzer.py INFO    : Start testing of classifier 116 / 200
# 2022-11-29 12:30:54 base_stability_analyzer.py INFO    : Classifier 116 / 200 was tested
# 2022-11-29 12:30:54 base_stability_analyzer.py INFO    : Start testing of classifier 117 / 200
# 2022-11-29 12:30:54 base_stability_analyzer.py INFO    : Classifier 117 / 200 was tested
# 2022-11-29 12:30:54 base_stability_analyzer.py INFO    : Start testing of classifier 118 / 200
# 2022-11-29 12:30:55 base_stability_analyzer.py INFO    : Classifier 118 / 200 was tested
# 2022-11-29 12:30:55 base_stability_analyzer.py INFO    : Start testing of classifier 119 / 200
# 2022-11-29 12:30:55 base_stability_analyzer.py INFO    : Classifier 119 / 200 was tested
# 2022-11-29 12:30:55 base_stability_analyzer.py INFO    : Start testing of classifier 120 / 200
# 2022-11-29 12:30:56 base_stability_analyzer.py INFO    : Classifier 120 / 200 was tested
# 2022-11-29 12:30:56 base_stability_analyzer.py INFO    : Start testing of classifier 121 / 200
# 2022-11-29 12:30:57 base_stability_analyzer.py INFO    : Classifier 121 / 200 was tested
# 2022-11-29 12:30:57 base_stability_analyzer.py INFO    : Start testing of classifier 122 / 200
# 2022-11-29 12:30:57 base_stability_analyzer.py INFO    : Classifier 122 / 200 was tested
# 2022-11-29 12:30:57 base_stability_analyzer.py INFO    : Start testing of classifier 123 / 200
# 2022-11-29 12:30:58 base_stability_analyzer.py INFO    : Classifier 123 / 200 was tested
# 2022-11-29 12:30:58 base_stability_analyzer.py INFO    : Start testing of classifier 124 / 200
# 2022-11-29 12:30:59 base_stability_analyzer.py INFO    : Classifier 124 / 200 was tested
# 2022-11-29 12:30:59 base_stability_analyzer.py INFO    : Start testing of classifier 125 / 200
# 2022-11-29 12:31:00 base_stability_analyzer.py INFO    : Classifier 125 / 200 was tested
# 2022-11-29 12:31:00 base_stability_analyzer.py INFO    : Start testing of classifier 126 / 200
# 2022-11-29 12:31:00 base_stability_analyzer.py INFO    : Classifier 126 / 200 was tested
# 2022-11-29 12:31:00 base_stability_analyzer.py INFO    : Start testing of classifier 127 / 200
# 2022-11-29 12:31:01 base_stability_analyzer.py INFO    : Classifier 127 / 200 was tested
# 2022-11-29 12:31:01 base_stability_analyzer.py INFO    : Start testing of classifier 128 / 200
# 2022-11-29 12:31:02 base_stability_analyzer.py INFO    : Classifier 128 / 200 was tested
# 2022-11-29 12:31:02 base_stability_analyzer.py INFO    : Start testing of classifier 129 / 200
# 2022-11-29 12:31:02 base_stability_analyzer.py INFO    : Classifier 129 / 200 was tested
# 2022-11-29 12:31:02 base_stability_analyzer.py INFO    : Start testing of classifier 130 / 200
# 2022-11-29 12:31:03 base_stability_analyzer.py INFO    : Classifier 130 / 200 was tested
# 2022-11-29 12:31:03 base_stability_analyzer.py INFO    : Start testing of classifier 131 / 200
# 2022-11-29 12:31:04 base_stability_analyzer.py INFO    : Classifier 131 / 200 was tested
# 2022-11-29 12:31:04 base_stability_analyzer.py INFO    : Start testing of classifier 132 / 200
# 2022-11-29 12:31:05 base_stability_analyzer.py INFO    : Classifier 132 / 200 was tested
# 2022-11-29 12:31:05 base_stability_analyzer.py INFO    : Start testing of classifier 133 / 200
# 2022-11-29 12:31:06 base_stability_analyzer.py INFO    : Classifier 133 / 200 was tested
# 2022-11-29 12:31:06 base_stability_analyzer.py INFO    : Start testing of classifier 134 / 200
# 2022-11-29 12:31:07 base_stability_analyzer.py INFO    : Classifier 134 / 200 was tested
# 2022-11-29 12:31:07 base_stability_analyzer.py INFO    : Start testing of classifier 135 / 200
# 2022-11-29 12:31:07 base_stability_analyzer.py INFO    : Classifier 135 / 200 was tested
# 2022-11-29 12:31:07 base_stability_analyzer.py INFO    : Start testing of classifier 136 / 200
# 2022-11-29 12:31:08 base_stability_analyzer.py INFO    : Classifier 136 / 200 was tested
# 2022-11-29 12:31:08 base_stability_analyzer.py INFO    : Start testing of classifier 137 / 200
# 2022-11-29 12:31:09 base_stability_analyzer.py INFO    : Classifier 137 / 200 was tested
# 2022-11-29 12:31:09 base_stability_analyzer.py INFO    : Start testing of classifier 138 / 200
# 2022-11-29 12:31:10 base_stability_analyzer.py INFO    : Classifier 138 / 200 was tested
# 2022-11-29 12:31:10 base_stability_analyzer.py INFO    : Start testing of classifier 139 / 200
# 2022-11-29 12:31:11 base_stability_analyzer.py INFO    : Classifier 139 / 200 was tested
# 2022-11-29 12:31:11 base_stability_analyzer.py INFO    : Start testing of classifier 140 / 200
# 2022-11-29 12:31:12 base_stability_analyzer.py INFO    : Classifier 140 / 200 was tested
# 2022-11-29 12:31:12 base_stability_analyzer.py INFO    : Start testing of classifier 141 / 200
# 2022-11-29 12:31:13 base_stability_analyzer.py INFO    : Classifier 141 / 200 was tested
# 2022-11-29 12:31:13 base_stability_analyzer.py INFO    : Start testing of classifier 142 / 200
# 2022-11-29 12:31:14 base_stability_analyzer.py INFO    : Classifier 142 / 200 was tested
# 2022-11-29 12:31:14 base_stability_analyzer.py INFO    : Start testing of classifier 143 / 200
# 2022-11-29 12:31:15 base_stability_analyzer.py INFO    : Classifier 143 / 200 was tested
# 2022-11-29 12:31:15 base_stability_analyzer.py INFO    : Start testing of classifier 144 / 200
# 2022-11-29 12:31:16 base_stability_analyzer.py INFO    : Classifier 144 / 200 was tested
# 2022-11-29 12:31:16 base_stability_analyzer.py INFO    : Start testing of classifier 145 / 200
# 2022-11-29 12:31:16 base_stability_analyzer.py INFO    : Classifier 145 / 200 was tested
# 2022-11-29 12:31:16 base_stability_analyzer.py INFO    : Start testing of classifier 146 / 200
# 2022-11-29 12:31:17 base_stability_analyzer.py INFO    : Classifier 146 / 200 was tested
# 2022-11-29 12:31:17 base_stability_analyzer.py INFO    : Start testing of classifier 147 / 200
# 2022-11-29 12:31:18 base_stability_analyzer.py INFO    : Classifier 147 / 200 was tested
# 2022-11-29 12:31:18 base_stability_analyzer.py INFO    : Start testing of classifier 148 / 200
# 2022-11-29 12:31:19 base_stability_analyzer.py INFO    : Classifier 148 / 200 was tested
# 2022-11-29 12:31:19 base_stability_analyzer.py INFO    : Start testing of classifier 149 / 200
# 2022-11-29 12:31:20 base_stability_analyzer.py INFO    : Classifier 149 / 200 was tested
# 2022-11-29 12:31:20 base_stability_analyzer.py INFO    : Start testing of classifier 150 / 200
# 2022-11-29 12:31:21 base_stability_analyzer.py INFO    : Classifier 150 / 200 was tested
# 2022-11-29 12:31:21 base_stability_analyzer.py INFO    : Start testing of classifier 151 / 200
# 2022-11-29 12:31:22 base_stability_analyzer.py INFO    : Classifier 151 / 200 was tested
# 2022-11-29 12:31:22 base_stability_analyzer.py INFO    : Start testing of classifier 152 / 200
# 2022-11-29 12:31:22 base_stability_analyzer.py INFO    : Classifier 152 / 200 was tested
# 2022-11-29 12:31:22 base_stability_analyzer.py INFO    : Start testing of classifier 153 / 200
# 2022-11-29 12:31:23 base_stability_analyzer.py INFO    : Classifier 153 / 200 was tested
# 2022-11-29 12:31:23 base_stability_analyzer.py INFO    : Start testing of classifier 154 / 200
# 2022-11-29 12:31:24 base_stability_analyzer.py INFO    : Classifier 154 / 200 was tested
# 2022-11-29 12:31:24 base_stability_analyzer.py INFO    : Start testing of classifier 155 / 200
# 2022-11-29 12:31:25 base_stability_analyzer.py INFO    : Classifier 155 / 200 was tested
# 2022-11-29 12:31:25 base_stability_analyzer.py INFO    : Start testing of classifier 156 / 200
# 2022-11-29 12:31:25 base_stability_analyzer.py INFO    : Classifier 156 / 200 was tested
# 2022-11-29 12:31:25 base_stability_analyzer.py INFO    : Start testing of classifier 157 / 200
# 2022-11-29 12:31:26 base_stability_analyzer.py INFO    : Classifier 157 / 200 was tested
# 2022-11-29 12:31:26 base_stability_analyzer.py INFO    : Start testing of classifier 158 / 200
# 2022-11-29 12:31:27 base_stability_analyzer.py INFO    : Classifier 158 / 200 was tested
# 2022-11-29 12:31:27 base_stability_analyzer.py INFO    : Start testing of classifier 159 / 200
# 2022-11-29 12:31:27 base_stability_analyzer.py INFO    : Classifier 159 / 200 was tested
# 2022-11-29 12:31:27 base_stability_analyzer.py INFO    : Start testing of classifier 160 / 200
# 2022-11-29 12:31:28 base_stability_analyzer.py INFO    : Classifier 160 / 200 was tested
# 2022-11-29 12:31:28 base_stability_analyzer.py INFO    : Start testing of classifier 161 / 200
# 2022-11-29 12:31:29 base_stability_analyzer.py INFO    : Classifier 161 / 200 was tested
# 2022-11-29 12:31:29 base_stability_analyzer.py INFO    : Start testing of classifier 162 / 200
# 2022-11-29 12:31:30 base_stability_analyzer.py INFO    : Classifier 162 / 200 was tested
# 2022-11-29 12:31:30 base_stability_analyzer.py INFO    : Start testing of classifier 163 / 200
# 2022-11-29 12:31:31 base_stability_analyzer.py INFO    : Classifier 163 / 200 was tested
# 2022-11-29 12:31:31 base_stability_analyzer.py INFO    : Start testing of classifier 164 / 200
# 2022-11-29 12:31:32 base_stability_analyzer.py INFO    : Classifier 164 / 200 was tested
# 2022-11-29 12:31:32 base_stability_analyzer.py INFO    : Start testing of classifier 165 / 200
# 2022-11-29 12:31:32 base_stability_analyzer.py INFO    : Classifier 165 / 200 was tested
# 2022-11-29 12:31:32 base_stability_analyzer.py INFO    : Start testing of classifier 166 / 200
# 2022-11-29 12:31:33 base_stability_analyzer.py INFO    : Classifier 166 / 200 was tested
# 2022-11-29 12:31:33 base_stability_analyzer.py INFO    : Start testing of classifier 167 / 200
# 2022-11-29 12:31:34 base_stability_analyzer.py INFO    : Classifier 167 / 200 was tested
# 2022-11-29 12:31:34 base_stability_analyzer.py INFO    : Start testing of classifier 168 / 200
# 2022-11-29 12:31:35 base_stability_analyzer.py INFO    : Classifier 168 / 200 was tested
# 2022-11-29 12:31:35 base_stability_analyzer.py INFO    : Start testing of classifier 169 / 200
# 2022-11-29 12:31:35 base_stability_analyzer.py INFO    : Classifier 169 / 200 was tested
# 2022-11-29 12:31:35 base_stability_analyzer.py INFO    : Start testing of classifier 170 / 200
# 2022-11-29 12:31:36 base_stability_analyzer.py INFO    : Classifier 170 / 200 was tested
# 2022-11-29 12:31:36 base_stability_analyzer.py INFO    : Start testing of classifier 171 / 200
# 2022-11-29 12:31:37 base_stability_analyzer.py INFO    : Classifier 171 / 200 was tested
# 2022-11-29 12:31:37 base_stability_analyzer.py INFO    : Start testing of classifier 172 / 200
# 2022-11-29 12:31:39 base_stability_analyzer.py INFO    : Classifier 172 / 200 was tested
# 2022-11-29 12:31:39 base_stability_analyzer.py INFO    : Start testing of classifier 173 / 200
# 2022-11-29 12:31:39 base_stability_analyzer.py INFO    : Classifier 173 / 200 was tested
# 2022-11-29 12:31:39 base_stability_analyzer.py INFO    : Start testing of classifier 174 / 200
# 2022-11-29 12:31:40 base_stability_analyzer.py INFO    : Classifier 174 / 200 was tested
# 2022-11-29 12:31:40 base_stability_analyzer.py INFO    : Start testing of classifier 175 / 200
# 2022-11-29 12:31:41 base_stability_analyzer.py INFO    : Classifier 175 / 200 was tested
# 2022-11-29 12:31:41 base_stability_analyzer.py INFO    : Start testing of classifier 176 / 200
# 2022-11-29 12:31:42 base_stability_analyzer.py INFO    : Classifier 176 / 200 was tested
# 2022-11-29 12:31:42 base_stability_analyzer.py INFO    : Start testing of classifier 177 / 200
# 2022-11-29 12:31:42 base_stability_analyzer.py INFO    : Classifier 177 / 200 was tested
# 2022-11-29 12:31:42 base_stability_analyzer.py INFO    : Start testing of classifier 178 / 200
# 2022-11-29 12:31:43 base_stability_analyzer.py INFO    : Classifier 178 / 200 was tested
# 2022-11-29 12:31:43 base_stability_analyzer.py INFO    : Start testing of classifier 179 / 200
# 2022-11-29 12:31:44 base_stability_analyzer.py INFO    : Classifier 179 / 200 was tested
# 2022-11-29 12:31:44 base_stability_analyzer.py INFO    : Start testing of classifier 180 / 200
# 2022-11-29 12:31:44 base_stability_analyzer.py INFO    : Classifier 180 / 200 was tested
# 2022-11-29 12:31:44 base_stability_analyzer.py INFO    : Start testing of classifier 181 / 200
# 2022-11-29 12:31:45 base_stability_analyzer.py INFO    : Classifier 181 / 200 was tested
# 2022-11-29 12:31:45 base_stability_analyzer.py INFO    : Start testing of classifier 182 / 200
# 2022-11-29 12:31:46 base_stability_analyzer.py INFO    : Classifier 182 / 200 was tested
# 2022-11-29 12:31:46 base_stability_analyzer.py INFO    : Start testing of classifier 183 / 200
# 2022-11-29 12:31:46 base_stability_analyzer.py INFO    : Classifier 183 / 200 was tested
# 2022-11-29 12:31:46 base_stability_analyzer.py INFO    : Start testing of classifier 184 / 200
# 2022-11-29 12:31:47 base_stability_analyzer.py INFO    : Classifier 184 / 200 was tested
# 2022-11-29 12:31:47 base_stability_analyzer.py INFO    : Start testing of classifier 185 / 200
# 2022-11-29 12:31:48 base_stability_analyzer.py INFO    : Classifier 185 / 200 was tested
# 2022-11-29 12:31:48 base_stability_analyzer.py INFO    : Start testing of classifier 186 / 200
# 2022-11-29 12:31:49 base_stability_analyzer.py INFO    : Classifier 186 / 200 was tested
# 2022-11-29 12:31:49 base_stability_analyzer.py INFO    : Start testing of classifier 187 / 200
# 2022-11-29 12:31:49 base_stability_analyzer.py INFO    : Classifier 187 / 200 was tested
# 2022-11-29 12:31:49 base_stability_analyzer.py INFO    : Start testing of classifier 188 / 200
# 2022-11-29 12:31:50 base_stability_analyzer.py INFO    : Classifier 188 / 200 was tested
# 2022-11-29 12:31:50 base_stability_analyzer.py INFO    : Start testing of classifier 189 / 200
# 2022-11-29 12:31:51 base_stability_analyzer.py INFO    : Classifier 189 / 200 was tested
# 2022-11-29 12:31:51 base_stability_analyzer.py INFO    : Start testing of classifier 190 / 200
# 2022-11-29 12:31:52 base_stability_analyzer.py INFO    : Classifier 190 / 200 was tested
# 2022-11-29 12:31:52 base_stability_analyzer.py INFO    : Start testing of classifier 191 / 200
# 2022-11-29 12:31:53 base_stability_analyzer.py INFO    : Classifier 191 / 200 was tested
# 2022-11-29 12:31:53 base_stability_analyzer.py INFO    : Start testing of classifier 192 / 200
# 2022-11-29 12:31:53 base_stability_analyzer.py INFO    : Classifier 192 / 200 was tested
# 2022-11-29 12:31:53 base_stability_analyzer.py INFO    : Start testing of classifier 193 / 200
# 2022-11-29 12:31:54 base_stability_analyzer.py INFO    : Classifier 193 / 200 was tested
# 2022-11-29 12:31:54 base_stability_analyzer.py INFO    : Start testing of classifier 194 / 200
# 2022-11-29 12:31:54 base_stability_analyzer.py INFO    : Classifier 194 / 200 was tested
# 2022-11-29 12:31:54 base_stability_analyzer.py INFO    : Start testing of classifier 195 / 200
# 2022-11-29 12:31:55 base_stability_analyzer.py INFO    : Classifier 195 / 200 was tested
# 2022-11-29 12:31:55 base_stability_analyzer.py INFO    : Start testing of classifier 196 / 200
# 2022-11-29 12:31:56 base_stability_analyzer.py INFO    : Classifier 196 / 200 was tested
# 2022-11-29 12:31:56 base_stability_analyzer.py INFO    : Start testing of classifier 197 / 200
# 2022-11-29 12:31:56 base_stability_analyzer.py INFO    : Classifier 197 / 200 was tested
# 2022-11-29 12:31:56 base_stability_analyzer.py INFO    : Start testing of classifier 198 / 200
# 2022-11-29 12:31:57 base_stability_analyzer.py INFO    : Classifier 198 / 200 was tested
# 2022-11-29 12:31:57 base_stability_analyzer.py INFO    : Start testing of classifier 199 / 200
# 2022-11-29 12:31:57 base_stability_analyzer.py INFO    : Classifier 199 / 200 was tested
# 2022-11-29 12:31:57 base_stability_analyzer.py INFO    : Start testing of classifier 200 / 200
# 2022-11-29 12:31:58 base_stability_analyzer.py INFO    : Classifier 200 / 200 was tested
# results.shape --  (200, 8717)
#
#
# ##############################  Stability metrics  ##############################
# General Ensemble Accuracy: 0.805
# Mean: 0.5838
# Std: 0.0525
# IQR: 0.029
# Entropy: 4.1131
# Jitter: 0.491
# Per sample accuracy: 0.7998
# Label stability: 0.9491
