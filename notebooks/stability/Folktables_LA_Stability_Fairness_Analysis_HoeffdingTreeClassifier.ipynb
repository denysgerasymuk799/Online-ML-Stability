# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
import pandas as pd
import seaborn as sns

from river import compose
from river import preprocessing
from river import tree
from sklearn.model_selection import train_test_split

from source.config import *
from source.utils.analysis_helper import load_groups_of_interest
from source.stability.incremental_stability_analyzer import IncrementalStabilityAnalyzer
from source.stability.stability_fairness_analyzer import StabilityFairnessAnalyzer
from source.utils.incremental_model_utils import train_incremental_model
from source.data_loaders.folktables_dataset_from_pd import FolktablesDatasetFromPandas

# %%
sns.set(rc={'figure.figsize':(15, 5)})
dataset_name = 'folktables'
dataset_config = DATASETS_CONFIG[dataset_name]
TARGET_COLUMN = dataset_config['target_column']

# %%
# Creating a data frame
df = pd.read_csv("../../datasets/folktables-LA-2018.csv", delimiter=',')
df.head()
# Out:
#    AGEP  SCHL  MAR  RELP  DIS  ESP  CIT  MIG  MIL  ANC  NATIVITY  DEAR  DEYE  \
# 0    29    18    5    16    2    0    1    1    4    2         1     2     2
# 1    17    13    5    16    2    0    1    1    4    1         1     2     2
# 2    37    13    5    16    2    0    1    1    4    1         1     2     2
# 3    86    12    2    16    1    0    1    1    4    1         1     2     1
# 4    22    19    5    17    2    0    1    1    4    1         1     2     2
#
#    DREM  SEX  RAC1P  ESR
# 0     2    1      1    0
# 1     2    1      2    0
# 2     2    1      1    0
# 3     2    2      2    0
# 4     2    2      1    0

# %%
df.shape
# Out:
# (43588, 17)

# %%
df.columns
# Out:
# Index(['AGEP', 'SCHL', 'MAR', 'RELP', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
#        'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'SEX', 'RAC1P', 'ESR'],
#       dtype='object')

# %%
df['ESR'].value_counts()
# Out:
# 0    25363
# 1    18225
# Name: ESR, dtype: int64

# %%
dataset_size = df.shape[0]
test_size = int(TEST_FRACTION * dataset_size)
validation_size = test_size

train_cv_df, test_df = train_test_split(df, test_size=test_size, random_state=SEED)
train_df, cv_df = train_test_split(train_cv_df, test_size=validation_size, random_state=SEED)
print("train_df shape: ", train_df.shape)
print("cv_df shape: ", cv_df.shape)
print("test_df shape: ", test_df.shape)
# Out:
# train_df shape:  (26154, 17)
# cv_df shape:  (8717, 17)
# test_df shape:  (8717, 17)

# %%
train_df = train_df[:10_000]
cv_df = cv_df[:5000]
test_df = test_df[:5000]

# %%
train_dataset = FolktablesDatasetFromPandas(pd_dataset=train_df)

# %%
numerical_features = dataset_config['numerical_features']
categorical_features = [feature for feature in df.columns if feature not in numerical_features + [TARGET_COLUMN]]

categorical_features
# Out:
# ['MAR',
#  'RELP',
#  'DIS',
#  'ESP',
#  'CIT',
#  'MIG',
#  'MIL',
#  'ANC',
#  'NATIVITY',
#  'DEAR',
#  'DEYE',
#  'DREM',
#  'SEX',
#  'RAC1P']

# %% [markdown]
# ### Apply data transformations

# %%
def get_transform_pipeline(categorical_features, numerical_features):
    transform_pipeline = compose.Select(categorical_features[0])
    for feature in categorical_features[1:]:
        transform_pipeline += compose.Select(feature)
    transform_pipeline |= preprocessing.OneHotEncoder()

    for feature in numerical_features:
        transform_pipeline += compose.Select(feature)
    transform_pipeline |= preprocessing.MinMaxScaler()

    return transform_pipeline

# %%
transform_pipeline = get_transform_pipeline(categorical_features, numerical_features)

for idx, (x, y) in enumerate(train_dataset):
    print(f'Initial features: {x}\n')
    x = transform_pipeline.transform_one(x)
    print(f'Transformed features: {x}\n\n')
    if idx + 1 == 10:
        break
# Out:
# Initial features: {'AGEP': 93, 'SCHL': 19, 'MAR': '3', 'RELP': '0', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '4', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '1', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 58, 'SCHL': 23, 'MAR': '3', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 1.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 0.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 69, 'SCHL': 17, 'MAR': '3', 'RELP': '0', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.3142857142857143, 'RAC1P_1': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_0': 0.0, 'MAR_3': 0.0}
#
#
# Initial features: {'AGEP': 28, 'SCHL': 22, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '4', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.8333333333333334, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 1.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0, 'MAR_1': 0.0}
#
#
# Initial features: {'AGEP': 35, 'SCHL': 16, 'MAR': '5', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '2'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.1076923076923077, 'RAC1P_2': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'ANC_1': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0, 'MAR_1': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 66, 'SCHL': 16, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.5846153846153846, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'ANC_1': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0, 'MAR_1': 1.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 41, 'SCHL': 18, 'MAR': '1', 'RELP': '0', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.2857142857142857, 'AGEP': 0.2, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_2': 0.0, 'SEX_1': 1.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 1.0, 'ANC_4': 0.0, 'ANC_1': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'MAR_3': 0.0, 'MAR_1': 1.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 15, 'SCHL': 11, 'MAR': '5', 'RELP': '2', 'DIS': '1', 'ESP': '2', 'CIT': '1', 'MIG': '1', 'MIL': '0', 'ANC': '3', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '1', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_2': 0.0, 'SEX_1': 1.0, 'DREM_2': 0.0, 'DREM_1': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'ANC_3': 0.0, 'ANC_1': 0.0, 'MIL_0': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 0.0, 'ESP_2': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'MAR_3': 0.0, 'MAR_1': 0.0, 'MAR_5': 1.0}
#
#
# Initial features: {'AGEP': 51, 'SCHL': 16, 'MAR': '1', 'RELP': '1', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '2'}
#
# Transformed features: {'SCHL': 0.4166666666666667, 'AGEP': 0.46153846153846156, 'RAC1P_2': 1.0, 'RAC1P_1': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 1.0, 'DREM_1': 0.0, 'DEYE_2': 0.0, 'DEYE_1': 0.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'ANC_3': 0.0, 'ANC_1': 1.0, 'MIL_0': 0.0, 'MIL_4': 1.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 1.0, 'ESP_2': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'RELP_1': 0.0, 'MAR_3': 0.0, 'MAR_1': 1.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 73, 'SCHL': 15, 'MAR': '1', 'RELP': '1', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '1', 'DREM': '1', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.3333333333333333, 'AGEP': 0.7435897435897436, 'RAC1P_2': 0.0, 'RAC1P_1': 1.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DREM_1': 1.0, 'DEYE_2': 0.0, 'DEYE_1': 1.0, 'DEAR_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_2': 0.0, 'ANC_4': 0.0, 'ANC_3': 0.0, 'ANC_1': 1.0, 'MIL_0': 0.0, 'MIL_4': 1.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 0.0, 'ESP_0': 1.0, 'ESP_2': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_0': 0.0, 'RELP_2': 0.0, 'RELP_1': 0.0, 'MAR_3': 0.0, 'MAR_1': 1.0, 'MAR_5': 0.0}

# %% [markdown]
# ### Analyze stability of Adaptive Random Forest classifier

# %%
def get_base_model():
    return tree.HoeffdingTreeClassifier(grace_period=50, delta=0.01), 'HoeffdingTreeClassifier'

# %%
base_model, base_model_name = get_base_model()

# Conduct model training
base_model = train_incremental_model(base_model, train_dataset, train_df.shape[0])
# Out:
# 2022-11-22 00:48:11 incremental_model_utils.py INFO    : Iteration 1000/10000 -- Accuracy: 72.37%; WeightedF1: 72.52%
# 2022-11-22 00:48:11 incremental_model_utils.py INFO    : Iteration 2000/10000 -- Accuracy: 74.64%; WeightedF1: 74.75%
# 2022-11-22 00:48:12 incremental_model_utils.py INFO    : Iteration 3000/10000 -- Accuracy: 75.59%; WeightedF1: 75.72%
# 2022-11-22 00:48:12 incremental_model_utils.py INFO    : Iteration 4000/10000 -- Accuracy: 75.79%; WeightedF1: 75.94%
# 2022-11-22 00:48:12 incremental_model_utils.py INFO    : Iteration 5000/10000 -- Accuracy: 76.70%; WeightedF1: 76.82%
# 2022-11-22 00:48:12 incremental_model_utils.py INFO    : Iteration 6000/10000 -- Accuracy: 76.16%; WeightedF1: 76.29%
# 2022-11-22 00:48:12 incremental_model_utils.py INFO    : Iteration 7000/10000 -- Accuracy: 76.50%; WeightedF1: 76.63%
# 2022-11-22 00:48:12 incremental_model_utils.py INFO    : Iteration 8000/10000 -- Accuracy: 76.67%; WeightedF1: 76.81%
# 2022-11-22 00:48:13 incremental_model_utils.py INFO    : Iteration 9000/10000 -- Accuracy: 76.90%; WeightedF1: 77.05%
# 2022-11-22 00:48:13 incremental_model_utils.py INFO    : Iteration 10000/10000 -- Accuracy: 77.09%; WeightedF1: 77.22%
# Metrics after incremental model training:
# Accuracy: 77.09%
# WeightedF1: 77.22%

# %%
X_test_df = test_df.drop([TARGET_COLUMN], axis=1)
test_groups = load_groups_of_interest(group_info=TEST_GROUPS_CONFIG['folktables'], X_test_df=X_test_df)
stability_analyzer = IncrementalStabilityAnalyzer(base_model,
                                                  base_model_name=base_model_name,
                                                  train_pd_dataset=cv_df,
                                                  test_pd_dataset=test_df,
                                                  test_y_true=test_df[TARGET_COLUMN],
                                                  dataset_reader=FolktablesDatasetFromPandas,
                                                  dataset_name=dataset_name + '_LA',
                                                  n_estimators=100)

stability_fairness_analyzer = StabilityFairnessAnalyzer(stability_analyzer, test_groups)

# %%
stability_fairness_analyzer.measure_metrics(make_plots=True)
# Out:
# 2022-11-22 00:48:17 base_stability_analyzer.py INFO    : Start testing of classifier 1 / 100
# 2022-11-22 00:48:17 base_stability_analyzer.py INFO    : Classifier 1 / 100 was tested
# 2022-11-22 00:48:17 base_stability_analyzer.py INFO    : Start testing of classifier 2 / 100
# 2022-11-22 00:48:18 base_stability_analyzer.py INFO    : Classifier 2 / 100 was tested
# 2022-11-22 00:48:18 base_stability_analyzer.py INFO    : Start testing of classifier 3 / 100
# 2022-11-22 00:48:18 base_stability_analyzer.py INFO    : Classifier 3 / 100 was tested
# 2022-11-22 00:48:18 base_stability_analyzer.py INFO    : Start testing of classifier 4 / 100
# 2022-11-22 00:48:18 base_stability_analyzer.py INFO    : Classifier 4 / 100 was tested
# 2022-11-22 00:48:18 base_stability_analyzer.py INFO    : Start testing of classifier 5 / 100
# 2022-11-22 00:48:19 base_stability_analyzer.py INFO    : Classifier 5 / 100 was tested
# 2022-11-22 00:48:19 base_stability_analyzer.py INFO    : Start testing of classifier 6 / 100
# 2022-11-22 00:48:19 base_stability_analyzer.py INFO    : Classifier 6 / 100 was tested
# 2022-11-22 00:48:19 base_stability_analyzer.py INFO    : Start testing of classifier 7 / 100
# 2022-11-22 00:48:19 base_stability_analyzer.py INFO    : Classifier 7 / 100 was tested
# 2022-11-22 00:48:19 base_stability_analyzer.py INFO    : Start testing of classifier 8 / 100
# 2022-11-22 00:48:20 base_stability_analyzer.py INFO    : Classifier 8 / 100 was tested
# 2022-11-22 00:48:20 base_stability_analyzer.py INFO    : Start testing of classifier 9 / 100
# 2022-11-22 00:48:20 base_stability_analyzer.py INFO    : Classifier 9 / 100 was tested
# 2022-11-22 00:48:20 base_stability_analyzer.py INFO    : Start testing of classifier 10 / 100
# 2022-11-22 00:48:20 base_stability_analyzer.py INFO    : Classifier 10 / 100 was tested
# 2022-11-22 00:48:20 base_stability_analyzer.py INFO    : Start testing of classifier 11 / 100
# 2022-11-22 00:48:21 base_stability_analyzer.py INFO    : Classifier 11 / 100 was tested
# 2022-11-22 00:48:21 base_stability_analyzer.py INFO    : Start testing of classifier 12 / 100
# 2022-11-22 00:48:21 base_stability_analyzer.py INFO    : Classifier 12 / 100 was tested
# 2022-11-22 00:48:21 base_stability_analyzer.py INFO    : Start testing of classifier 13 / 100
# 2022-11-22 00:48:21 base_stability_analyzer.py INFO    : Classifier 13 / 100 was tested
# 2022-11-22 00:48:21 base_stability_analyzer.py INFO    : Start testing of classifier 14 / 100
# 2022-11-22 00:48:22 base_stability_analyzer.py INFO    : Classifier 14 / 100 was tested
# 2022-11-22 00:48:22 base_stability_analyzer.py INFO    : Start testing of classifier 15 / 100
# 2022-11-22 00:48:22 base_stability_analyzer.py INFO    : Classifier 15 / 100 was tested
# 2022-11-22 00:48:22 base_stability_analyzer.py INFO    : Start testing of classifier 16 / 100
# 2022-11-22 00:48:22 base_stability_analyzer.py INFO    : Classifier 16 / 100 was tested
# 2022-11-22 00:48:22 base_stability_analyzer.py INFO    : Start testing of classifier 17 / 100
# 2022-11-22 00:48:23 base_stability_analyzer.py INFO    : Classifier 17 / 100 was tested
# 2022-11-22 00:48:23 base_stability_analyzer.py INFO    : Start testing of classifier 18 / 100
# 2022-11-22 00:48:23 base_stability_analyzer.py INFO    : Classifier 18 / 100 was tested
# 2022-11-22 00:48:23 base_stability_analyzer.py INFO    : Start testing of classifier 19 / 100
# 2022-11-22 00:48:23 base_stability_analyzer.py INFO    : Classifier 19 / 100 was tested
# 2022-11-22 00:48:23 base_stability_analyzer.py INFO    : Start testing of classifier 20 / 100
# 2022-11-22 00:48:24 base_stability_analyzer.py INFO    : Classifier 20 / 100 was tested
# 2022-11-22 00:48:24 base_stability_analyzer.py INFO    : Start testing of classifier 21 / 100
# 2022-11-22 00:48:24 base_stability_analyzer.py INFO    : Classifier 21 / 100 was tested
# 2022-11-22 00:48:24 base_stability_analyzer.py INFO    : Start testing of classifier 22 / 100
# 2022-11-22 00:48:25 base_stability_analyzer.py INFO    : Classifier 22 / 100 was tested
# 2022-11-22 00:48:25 base_stability_analyzer.py INFO    : Start testing of classifier 23 / 100
# 2022-11-22 00:48:25 base_stability_analyzer.py INFO    : Classifier 23 / 100 was tested
# 2022-11-22 00:48:25 base_stability_analyzer.py INFO    : Start testing of classifier 24 / 100
# 2022-11-22 00:48:25 base_stability_analyzer.py INFO    : Classifier 24 / 100 was tested
# 2022-11-22 00:48:25 base_stability_analyzer.py INFO    : Start testing of classifier 25 / 100
# 2022-11-22 00:48:26 base_stability_analyzer.py INFO    : Classifier 25 / 100 was tested
# 2022-11-22 00:48:26 base_stability_analyzer.py INFO    : Start testing of classifier 26 / 100
# 2022-11-22 00:48:26 base_stability_analyzer.py INFO    : Classifier 26 / 100 was tested
# 2022-11-22 00:48:26 base_stability_analyzer.py INFO    : Start testing of classifier 27 / 100
# 2022-11-22 00:48:26 base_stability_analyzer.py INFO    : Classifier 27 / 100 was tested
# 2022-11-22 00:48:26 base_stability_analyzer.py INFO    : Start testing of classifier 28 / 100
# 2022-11-22 00:48:27 base_stability_analyzer.py INFO    : Classifier 28 / 100 was tested
# 2022-11-22 00:48:27 base_stability_analyzer.py INFO    : Start testing of classifier 29 / 100
# 2022-11-22 00:48:27 base_stability_analyzer.py INFO    : Classifier 29 / 100 was tested
# 2022-11-22 00:48:27 base_stability_analyzer.py INFO    : Start testing of classifier 30 / 100
# 2022-11-22 00:48:27 base_stability_analyzer.py INFO    : Classifier 30 / 100 was tested
# 2022-11-22 00:48:27 base_stability_analyzer.py INFO    : Start testing of classifier 31 / 100
# 2022-11-22 00:48:28 base_stability_analyzer.py INFO    : Classifier 31 / 100 was tested
# 2022-11-22 00:48:28 base_stability_analyzer.py INFO    : Start testing of classifier 32 / 100
# 2022-11-22 00:48:28 base_stability_analyzer.py INFO    : Classifier 32 / 100 was tested
# 2022-11-22 00:48:28 base_stability_analyzer.py INFO    : Start testing of classifier 33 / 100
# 2022-11-22 00:48:28 base_stability_analyzer.py INFO    : Classifier 33 / 100 was tested
# 2022-11-22 00:48:28 base_stability_analyzer.py INFO    : Start testing of classifier 34 / 100
# 2022-11-22 00:48:29 base_stability_analyzer.py INFO    : Classifier 34 / 100 was tested
# 2022-11-22 00:48:29 base_stability_analyzer.py INFO    : Start testing of classifier 35 / 100
# 2022-11-22 00:48:29 base_stability_analyzer.py INFO    : Classifier 35 / 100 was tested
# 2022-11-22 00:48:29 base_stability_analyzer.py INFO    : Start testing of classifier 36 / 100
# 2022-11-22 00:48:29 base_stability_analyzer.py INFO    : Classifier 36 / 100 was tested
# 2022-11-22 00:48:29 base_stability_analyzer.py INFO    : Start testing of classifier 37 / 100
# 2022-11-22 00:48:30 base_stability_analyzer.py INFO    : Classifier 37 / 100 was tested
# 2022-11-22 00:48:30 base_stability_analyzer.py INFO    : Start testing of classifier 38 / 100
# 2022-11-22 00:48:30 base_stability_analyzer.py INFO    : Classifier 38 / 100 was tested
# 2022-11-22 00:48:30 base_stability_analyzer.py INFO    : Start testing of classifier 39 / 100
# 2022-11-22 00:48:30 base_stability_analyzer.py INFO    : Classifier 39 / 100 was tested
# 2022-11-22 00:48:30 base_stability_analyzer.py INFO    : Start testing of classifier 40 / 100
# 2022-11-22 00:48:31 base_stability_analyzer.py INFO    : Classifier 40 / 100 was tested
# 2022-11-22 00:48:31 base_stability_analyzer.py INFO    : Start testing of classifier 41 / 100
# 2022-11-22 00:48:31 base_stability_analyzer.py INFO    : Classifier 41 / 100 was tested
# 2022-11-22 00:48:31 base_stability_analyzer.py INFO    : Start testing of classifier 42 / 100
# 2022-11-22 00:48:31 base_stability_analyzer.py INFO    : Classifier 42 / 100 was tested
# 2022-11-22 00:48:31 base_stability_analyzer.py INFO    : Start testing of classifier 43 / 100
# 2022-11-22 00:48:32 base_stability_analyzer.py INFO    : Classifier 43 / 100 was tested
# 2022-11-22 00:48:32 base_stability_analyzer.py INFO    : Start testing of classifier 44 / 100
# 2022-11-22 00:48:32 base_stability_analyzer.py INFO    : Classifier 44 / 100 was tested
# 2022-11-22 00:48:32 base_stability_analyzer.py INFO    : Start testing of classifier 45 / 100
# 2022-11-22 00:48:32 base_stability_analyzer.py INFO    : Classifier 45 / 100 was tested
# 2022-11-22 00:48:32 base_stability_analyzer.py INFO    : Start testing of classifier 46 / 100
# 2022-11-22 00:48:33 base_stability_analyzer.py INFO    : Classifier 46 / 100 was tested
# 2022-11-22 00:48:33 base_stability_analyzer.py INFO    : Start testing of classifier 47 / 100
# 2022-11-22 00:48:33 base_stability_analyzer.py INFO    : Classifier 47 / 100 was tested
# 2022-11-22 00:48:33 base_stability_analyzer.py INFO    : Start testing of classifier 48 / 100
# 2022-11-22 00:48:33 base_stability_analyzer.py INFO    : Classifier 48 / 100 was tested
# 2022-11-22 00:48:33 base_stability_analyzer.py INFO    : Start testing of classifier 49 / 100
# 2022-11-22 00:48:34 base_stability_analyzer.py INFO    : Classifier 49 / 100 was tested
# 2022-11-22 00:48:34 base_stability_analyzer.py INFO    : Start testing of classifier 50 / 100
# 2022-11-22 00:48:34 base_stability_analyzer.py INFO    : Classifier 50 / 100 was tested
# 2022-11-22 00:48:34 base_stability_analyzer.py INFO    : Start testing of classifier 51 / 100
# 2022-11-22 00:48:35 base_stability_analyzer.py INFO    : Classifier 51 / 100 was tested
# 2022-11-22 00:48:35 base_stability_analyzer.py INFO    : Start testing of classifier 52 / 100
# 2022-11-22 00:48:35 base_stability_analyzer.py INFO    : Classifier 52 / 100 was tested
# 2022-11-22 00:48:35 base_stability_analyzer.py INFO    : Start testing of classifier 53 / 100
# 2022-11-22 00:48:35 base_stability_analyzer.py INFO    : Classifier 53 / 100 was tested
# 2022-11-22 00:48:35 base_stability_analyzer.py INFO    : Start testing of classifier 54 / 100
# 2022-11-22 00:48:36 base_stability_analyzer.py INFO    : Classifier 54 / 100 was tested
# 2022-11-22 00:48:36 base_stability_analyzer.py INFO    : Start testing of classifier 55 / 100
# 2022-11-22 00:48:36 base_stability_analyzer.py INFO    : Classifier 55 / 100 was tested
# 2022-11-22 00:48:36 base_stability_analyzer.py INFO    : Start testing of classifier 56 / 100
# 2022-11-22 00:48:36 base_stability_analyzer.py INFO    : Classifier 56 / 100 was tested
# 2022-11-22 00:48:36 base_stability_analyzer.py INFO    : Start testing of classifier 57 / 100
# 2022-11-22 00:48:37 base_stability_analyzer.py INFO    : Classifier 57 / 100 was tested
# 2022-11-22 00:48:37 base_stability_analyzer.py INFO    : Start testing of classifier 58 / 100
# 2022-11-22 00:48:37 base_stability_analyzer.py INFO    : Classifier 58 / 100 was tested
# 2022-11-22 00:48:37 base_stability_analyzer.py INFO    : Start testing of classifier 59 / 100
# 2022-11-22 00:48:37 base_stability_analyzer.py INFO    : Classifier 59 / 100 was tested
# 2022-11-22 00:48:37 base_stability_analyzer.py INFO    : Start testing of classifier 60 / 100
# 2022-11-22 00:48:38 base_stability_analyzer.py INFO    : Classifier 60 / 100 was tested
# 2022-11-22 00:48:38 base_stability_analyzer.py INFO    : Start testing of classifier 61 / 100
# 2022-11-22 00:48:38 base_stability_analyzer.py INFO    : Classifier 61 / 100 was tested
# 2022-11-22 00:48:38 base_stability_analyzer.py INFO    : Start testing of classifier 62 / 100
# 2022-11-22 00:48:38 base_stability_analyzer.py INFO    : Classifier 62 / 100 was tested
# 2022-11-22 00:48:38 base_stability_analyzer.py INFO    : Start testing of classifier 63 / 100
# 2022-11-22 00:48:39 base_stability_analyzer.py INFO    : Classifier 63 / 100 was tested
# 2022-11-22 00:48:39 base_stability_analyzer.py INFO    : Start testing of classifier 64 / 100
# 2022-11-22 00:48:39 base_stability_analyzer.py INFO    : Classifier 64 / 100 was tested
# 2022-11-22 00:48:39 base_stability_analyzer.py INFO    : Start testing of classifier 65 / 100
# 2022-11-22 00:48:39 base_stability_analyzer.py INFO    : Classifier 65 / 100 was tested
# 2022-11-22 00:48:39 base_stability_analyzer.py INFO    : Start testing of classifier 66 / 100
# 2022-11-22 00:48:40 base_stability_analyzer.py INFO    : Classifier 66 / 100 was tested
# 2022-11-22 00:48:40 base_stability_analyzer.py INFO    : Start testing of classifier 67 / 100
# 2022-11-22 00:48:40 base_stability_analyzer.py INFO    : Classifier 67 / 100 was tested
# 2022-11-22 00:48:40 base_stability_analyzer.py INFO    : Start testing of classifier 68 / 100
# 2022-11-22 00:48:40 base_stability_analyzer.py INFO    : Classifier 68 / 100 was tested
# 2022-11-22 00:48:40 base_stability_analyzer.py INFO    : Start testing of classifier 69 / 100
# 2022-11-22 00:48:41 base_stability_analyzer.py INFO    : Classifier 69 / 100 was tested
# 2022-11-22 00:48:41 base_stability_analyzer.py INFO    : Start testing of classifier 70 / 100
# 2022-11-22 00:48:41 base_stability_analyzer.py INFO    : Classifier 70 / 100 was tested
# 2022-11-22 00:48:41 base_stability_analyzer.py INFO    : Start testing of classifier 71 / 100
# 2022-11-22 00:48:42 base_stability_analyzer.py INFO    : Classifier 71 / 100 was tested
# 2022-11-22 00:48:42 base_stability_analyzer.py INFO    : Start testing of classifier 72 / 100
# 2022-11-22 00:48:42 base_stability_analyzer.py INFO    : Classifier 72 / 100 was tested
# 2022-11-22 00:48:42 base_stability_analyzer.py INFO    : Start testing of classifier 73 / 100
# 2022-11-22 00:48:43 base_stability_analyzer.py INFO    : Classifier 73 / 100 was tested
# 2022-11-22 00:48:43 base_stability_analyzer.py INFO    : Start testing of classifier 74 / 100
# 2022-11-22 00:48:43 base_stability_analyzer.py INFO    : Classifier 74 / 100 was tested
# 2022-11-22 00:48:43 base_stability_analyzer.py INFO    : Start testing of classifier 75 / 100
# 2022-11-22 00:48:43 base_stability_analyzer.py INFO    : Classifier 75 / 100 was tested
# 2022-11-22 00:48:43 base_stability_analyzer.py INFO    : Start testing of classifier 76 / 100
# 2022-11-22 00:48:44 base_stability_analyzer.py INFO    : Classifier 76 / 100 was tested
# 2022-11-22 00:48:44 base_stability_analyzer.py INFO    : Start testing of classifier 77 / 100
# 2022-11-22 00:48:44 base_stability_analyzer.py INFO    : Classifier 77 / 100 was tested
# 2022-11-22 00:48:44 base_stability_analyzer.py INFO    : Start testing of classifier 78 / 100
# 2022-11-22 00:48:44 base_stability_analyzer.py INFO    : Classifier 78 / 100 was tested
# 2022-11-22 00:48:44 base_stability_analyzer.py INFO    : Start testing of classifier 79 / 100
# 2022-11-22 00:48:45 base_stability_analyzer.py INFO    : Classifier 79 / 100 was tested
# 2022-11-22 00:48:45 base_stability_analyzer.py INFO    : Start testing of classifier 80 / 100
# 2022-11-22 00:48:45 base_stability_analyzer.py INFO    : Classifier 80 / 100 was tested
# 2022-11-22 00:48:45 base_stability_analyzer.py INFO    : Start testing of classifier 81 / 100
# 2022-11-22 00:48:45 base_stability_analyzer.py INFO    : Classifier 81 / 100 was tested
# 2022-11-22 00:48:45 base_stability_analyzer.py INFO    : Start testing of classifier 82 / 100
# 2022-11-22 00:48:46 base_stability_analyzer.py INFO    : Classifier 82 / 100 was tested
# 2022-11-22 00:48:46 base_stability_analyzer.py INFO    : Start testing of classifier 83 / 100
# 2022-11-22 00:48:46 base_stability_analyzer.py INFO    : Classifier 83 / 100 was tested
# 2022-11-22 00:48:46 base_stability_analyzer.py INFO    : Start testing of classifier 84 / 100
# 2022-11-22 00:48:47 base_stability_analyzer.py INFO    : Classifier 84 / 100 was tested
# 2022-11-22 00:48:47 base_stability_analyzer.py INFO    : Start testing of classifier 85 / 100
# 2022-11-22 00:48:47 base_stability_analyzer.py INFO    : Classifier 85 / 100 was tested
# 2022-11-22 00:48:47 base_stability_analyzer.py INFO    : Start testing of classifier 86 / 100
# 2022-11-22 00:48:47 base_stability_analyzer.py INFO    : Classifier 86 / 100 was tested
# 2022-11-22 00:48:47 base_stability_analyzer.py INFO    : Start testing of classifier 87 / 100
# 2022-11-22 00:48:48 base_stability_analyzer.py INFO    : Classifier 87 / 100 was tested
# 2022-11-22 00:48:48 base_stability_analyzer.py INFO    : Start testing of classifier 88 / 100
# 2022-11-22 00:48:48 base_stability_analyzer.py INFO    : Classifier 88 / 100 was tested
# 2022-11-22 00:48:48 base_stability_analyzer.py INFO    : Start testing of classifier 89 / 100
# 2022-11-22 00:48:48 base_stability_analyzer.py INFO    : Classifier 89 / 100 was tested
# 2022-11-22 00:48:48 base_stability_analyzer.py INFO    : Start testing of classifier 90 / 100
# 2022-11-22 00:48:49 base_stability_analyzer.py INFO    : Classifier 90 / 100 was tested
# 2022-11-22 00:48:49 base_stability_analyzer.py INFO    : Start testing of classifier 91 / 100
# 2022-11-22 00:48:49 base_stability_analyzer.py INFO    : Classifier 91 / 100 was tested
# 2022-11-22 00:48:49 base_stability_analyzer.py INFO    : Start testing of classifier 92 / 100
# 2022-11-22 00:48:49 base_stability_analyzer.py INFO    : Classifier 92 / 100 was tested
# 2022-11-22 00:48:49 base_stability_analyzer.py INFO    : Start testing of classifier 93 / 100
# 2022-11-22 00:48:50 base_stability_analyzer.py INFO    : Classifier 93 / 100 was tested
# 2022-11-22 00:48:50 base_stability_analyzer.py INFO    : Start testing of classifier 94 / 100
# 2022-11-22 00:48:50 base_stability_analyzer.py INFO    : Classifier 94 / 100 was tested
# 2022-11-22 00:48:50 base_stability_analyzer.py INFO    : Start testing of classifier 95 / 100
# 2022-11-22 00:48:50 base_stability_analyzer.py INFO    : Classifier 95 / 100 was tested
# 2022-11-22 00:48:50 base_stability_analyzer.py INFO    : Start testing of classifier 96 / 100
# 2022-11-22 00:48:51 base_stability_analyzer.py INFO    : Classifier 96 / 100 was tested
# 2022-11-22 00:48:51 base_stability_analyzer.py INFO    : Start testing of classifier 97 / 100
# 2022-11-22 00:48:51 base_stability_analyzer.py INFO    : Classifier 97 / 100 was tested
# 2022-11-22 00:48:51 base_stability_analyzer.py INFO    : Start testing of classifier 98 / 100
# 2022-11-22 00:48:52 base_stability_analyzer.py INFO    : Classifier 98 / 100 was tested
# 2022-11-22 00:48:52 base_stability_analyzer.py INFO    : Start testing of classifier 99 / 100
# 2022-11-22 00:48:52 base_stability_analyzer.py INFO    : Classifier 99 / 100 was tested
# 2022-11-22 00:48:52 base_stability_analyzer.py INFO    : Start testing of classifier 100 / 100
# 2022-11-22 00:48:52 base_stability_analyzer.py INFO    : Classifier 100 / 100 was tested
# ############################## Stability metrics ##############################
# General Ensemble Accuracy: 0.8036
# Mean: 0.4655
# Std: 0.0655
# IQR: 0.0369
# Per sample accuracy: 0.7968
# Label stability: 0.9431
# Jitter: 0.0424
# ##############################  Fairness metrics  ##############################
#
# #################### Accuracy ####################
#             Race     Sex  Race_Sex
# adv       0.8054  0.8282    0.8243
# disadv    0.7963  0.7799    0.7684
# Accuracy  0.0091  0.0483    0.0559
#
# #################### Disparate_Impact ####################
#                     Race     Sex  Race_Sex
# adv               0.4928  0.4593    0.4915
# disadv            0.4261  0.4843    0.4661
# Disparate_Impact  0.8647  1.0544    0.9482
#
# #################### Equal_Opportunity ####################
#                      Race     Sex  Race_Sex
# adv                0.8412  0.8407    0.8392
# disadv             0.8197  0.8268    0.8051
# Equal_Opportunity  0.0215  0.0139    0.0340
#
# #################### Statistical_Parity_Difference ####################
#                                  Race     Sex  Race_Sex
# adv                            1.1278  1.0888    1.0558
# disadv                         1.2253  1.1984    1.2132
# Statistical_Parity_Difference -0.0975 -0.1096   -0.1575
