# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import collections
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from river import ensemble
from river import compose
from river import preprocessing
from river import tree

from source.data_loaders.folktables_dataset import FolktablesDataset
from source.utils.river_utils import evaluate_binary_model

# %%
sns.set(rc={'figure.figsize':(15, 5)})

# %%
# Creating a data frame
df = pd.read_csv("../../datasets/folktables-NY-2018.csv", delimiter=',')
df.head()
# Out:
#    AGEP  SCHL  MAR  RELP  DIS  ESP  CIT  MIG  MIL  ANC  NATIVITY  DEAR  DEYE  \
# 0    26    21    5    17    2    0    5    1    4    1         2     2     2
# 1    21    20    5    17    2    0    1    3    4    1         1     2     2
# 2    18    16    5    17    2    0    2    3    4    1         1     2     2
# 3    85    16    2    16    1    0    1    1    4    4         1     1     2
# 4    19    19    5    17    2    0    1    1    4    2         1     2     2
#
#    DREM  SEX  RAC1P  ESR
# 0     2    2      1    0
# 1     2    1      1    1
# 2     2    2      8    0
# 3     1    2      1    0
# 4     2    2      1    1

# %%
df.columns
# Out:
# Index(['AGEP', 'SCHL', 'MAR', 'RELP', 'DIS', 'ESP', 'CIT', 'MIG', 'MIL', 'ANC',
#        'NATIVITY', 'DEAR', 'DEYE', 'DREM', 'SEX', 'RAC1P', 'ESR'],
#       dtype='object')

# %%
df['ESR'].value_counts()
# Out:
# 0    105498
# 1     91469
# Name: ESR, dtype: int64

# %%
dataset = FolktablesDataset(directory="../../datasets")
counts = collections.Counter(y for _, y in dataset)

for c, count in counts.items():
    print(f'{c}: {count} ({count / sum(counts.values()):.5%})')
# Out:
# 0: 105498 (53.56126%)
# 1: 91469 (46.43874%)

# %% [markdown]
# ### Predict with River classification models

# %% [markdown]
# #### Apply data transformations

# %%
TARGET_COLUMN = 'ESR'
numerical_features = ['AGEP', 'SCHL']
categorical_features = [feature for feature in df.columns if feature not in numerical_features + [TARGET_COLUMN]]

transform_pipeline = compose.Select(categorical_features[0])
for feature in categorical_features[1:]:
    transform_pipeline += compose.Select(feature)
transform_pipeline |= preprocessing.OneHotEncoder()

for feature in numerical_features:
    transform_pipeline += compose.Select(feature)
transform_pipeline |= preprocessing.MinMaxScaler()

for idx, (x, y) in enumerate(dataset):
    print(f'Initial features: {x}\n')
    x = transform_pipeline.transform_one(x)
    print(f'Transformed features: {x}\n\n')
    if idx + 1 == 10:
        break
# Out:
# Initial features: {'AGEP': 26, 'SCHL': 21, 'MAR': '5', 'RELP': '17', 'DIS': '2', 'ESP': '0', 'CIT': '5', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '2', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_2': 0.0, 'ANC_1': 0.0, 'MIL_4': 0.0, 'MIG_1': 0.0, 'CIT_5': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'RELP_17': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 21, 'SCHL': 20, 'MAR': '5', 'RELP': '17', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'SEX_2': 0.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'CIT_5': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'RELP_17': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 18, 'SCHL': 16, 'MAR': '5', 'RELP': '17', 'DIS': '2', 'ESP': '0', 'CIT': '2', 'MIG': '3', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '8'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.0, 'RAC1P_1': 0.0, 'RAC1P_8': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 0.0, 'CIT_1': 0.0, 'CIT_5': 0.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'RELP_17': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 85, 'SCHL': 16, 'MAR': '2', 'RELP': '16', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '4', 'NATIVITY': '1', 'DEAR': '1', 'DEYE': '2', 'DREM': '1', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 1.0, 'RAC1P_1': 1.0, 'RAC1P_8': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DREM_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 0.0, 'DEAR_1': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'ANC_4': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 1.0, 'CIT_5': 0.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'DIS_1': 0.0, 'RELP_17': 0.0, 'RELP_16': 0.0, 'MAR_2': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 19, 'SCHL': 19, 'MAR': '5', 'RELP': '17', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.6, 'AGEP': 0.014925373134328358, 'RAC1P_1': 1.0, 'RAC1P_8': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 1.0, 'DREM_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 1.0, 'DEAR_1': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 0.0, 'ANC_1': 0.0, 'ANC_4': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'CIT_1': 1.0, 'CIT_5': 0.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_17': 1.0, 'RELP_16': 0.0, 'MAR_2': 0.0, 'MAR_5': 1.0}
#
#
# Initial features: {'AGEP': 22, 'SCHL': 21, 'MAR': '5', 'RELP': '17', 'DIS': '2', 'ESP': '0', 'CIT': '5', 'MIG': '2', 'MIL': '4', 'ANC': '1', 'NATIVITY': '2', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '2', 'RAC1P': '6'}
#
# Transformed features: {'SCHL': 1.0, 'AGEP': 0.05970149253731343, 'RAC1P_1': 0.0, 'RAC1P_6': 0.0, 'RAC1P_8': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 1.0, 'DREM_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 1.0, 'DEAR_1': 0.0, 'NATIVITY_2': 1.0, 'NATIVITY_1': 0.0, 'ANC_1': 1.0, 'ANC_4': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 0.0, 'MIG_2': 0.0, 'CIT_1': 0.0, 'CIT_5': 1.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_17': 1.0, 'RELP_16': 0.0, 'MAR_2': 0.0, 'MAR_5': 1.0}
#
#
# Initial features: {'AGEP': 19, 'SCHL': 16, 'MAR': '5', 'RELP': '17', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '2', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '9'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.014925373134328358, 'RAC1P_1': 0.0, 'RAC1P_6': 0.0, 'RAC1P_9': 0.0, 'RAC1P_8': 0.0, 'SEX_2': 0.0, 'SEX_1': 1.0, 'DREM_2': 1.0, 'DREM_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 1.0, 'DEAR_1': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 1.0, 'ANC_1': 0.0, 'ANC_4': 0.0, 'ANC_2': 1.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'MIG_2': 0.0, 'CIT_1': 1.0, 'CIT_5': 0.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_17': 1.0, 'RELP_16': 0.0, 'MAR_2': 0.0, 'MAR_5': 1.0}
#
#
# Initial features: {'AGEP': 77, 'SCHL': 21, 'MAR': '3', 'RELP': '16', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '1', 'SEX': '1', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 1.0, 'AGEP': 0.8805970149253731, 'RAC1P_1': 1.0, 'RAC1P_6': 0.0, 'RAC1P_9': 0.0, 'RAC1P_8': 0.0, 'SEX_2': 0.0, 'SEX_1': 1.0, 'DREM_2': 0.0, 'DREM_1': 1.0, 'DEYE_2': 0.0, 'DEAR_2': 1.0, 'DEAR_1': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 1.0, 'ANC_1': 1.0, 'ANC_4': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'MIG_2': 0.0, 'CIT_1': 1.0, 'CIT_5': 0.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_17': 0.0, 'RELP_16': 1.0, 'MAR_3': 0.0, 'MAR_2': 0.0, 'MAR_5': 0.0}
#
#
# Initial features: {'AGEP': 23, 'SCHL': 16, 'MAR': '5', 'RELP': '16', 'DIS': '2', 'ESP': '0', 'CIT': '1', 'MIG': '3', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '2', 'SEX': '1', 'RAC1P': '2'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.07462686567164178, 'RAC1P_2': 0.0, 'RAC1P_9': 0.0, 'RAC1P_8': 0.0, 'RAC1P_1': 0.0, 'RAC1P_6': 0.0, 'SEX_2': 0.0, 'SEX_1': 1.0, 'DREM_2': 1.0, 'DREM_1': 0.0, 'DEYE_2': 0.0, 'DEAR_2': 1.0, 'DEAR_1': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 1.0, 'ANC_1': 1.0, 'ANC_4': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_3': 1.0, 'MIG_1': 0.0, 'MIG_2': 0.0, 'CIT_1': 1.0, 'CIT_5': 0.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 1.0, 'DIS_1': 0.0, 'RELP_17': 0.0, 'RELP_16': 1.0, 'MAR_3': 0.0, 'MAR_2': 0.0, 'MAR_5': 1.0}
#
#
# Initial features: {'AGEP': 56, 'SCHL': 1, 'MAR': '5', 'RELP': '17', 'DIS': '1', 'ESP': '0', 'CIT': '1', 'MIG': '1', 'MIL': '4', 'ANC': '1', 'NATIVITY': '1', 'DEAR': '2', 'DEYE': '2', 'DREM': '1', 'SEX': '2', 'RAC1P': '1'}
#
# Transformed features: {'SCHL': 0.0, 'AGEP': 0.5671641791044776, 'RAC1P_2': 0.0, 'RAC1P_9': 0.0, 'RAC1P_8': 0.0, 'RAC1P_1': 1.0, 'RAC1P_6': 0.0, 'SEX_2': 1.0, 'SEX_1': 0.0, 'DREM_2': 0.0, 'DREM_1': 1.0, 'DEYE_2': 0.0, 'DEAR_2': 1.0, 'DEAR_1': 0.0, 'NATIVITY_2': 0.0, 'NATIVITY_1': 1.0, 'ANC_1': 1.0, 'ANC_4': 0.0, 'ANC_2': 0.0, 'MIL_4': 0.0, 'MIG_3': 0.0, 'MIG_1': 1.0, 'MIG_2': 0.0, 'CIT_1': 1.0, 'CIT_5': 0.0, 'CIT_2': 0.0, 'ESP_0': 0.0, 'DIS_2': 0.0, 'DIS_1': 1.0, 'RELP_17': 1.0, 'RELP_16': 0.0, 'MAR_3': 0.0, 'MAR_2': 0.0, 'MAR_5': 1.0}

# %% [markdown]
# #### Predict with Adaptive Random Forest Classifier

# %%
ARF_model = transform_pipeline | ensemble.AdaptiveRandomForestClassifier(n_models=10, seed=42, split_criterion='gini')
evaluate_binary_model(dataset, ARF_model)
# Out:
# Index: 1000; Accuracy: 83.18%; WeightedF1: 77.72%
# Index: 2000; Accuracy: 82.59%; WeightedF1: 76.08%
# Index: 3000; Accuracy: 82.23%; WeightedF1: 75.61%
# Index: 4000; Accuracy: 82.57%; WeightedF1: 75.93%
# Index: 5000; Accuracy: 82.40%; WeightedF1: 75.63%
# Index: 6000; Accuracy: 82.68%; WeightedF1: 76.12%
# Index: 7000; Accuracy: 83.01%; WeightedF1: 76.57%
# Index: 8000; Accuracy: 83.34%; WeightedF1: 76.97%
# Index: 9000; Accuracy: 83.18%; WeightedF1: 76.78%
# Index: 10000; Accuracy: 83.33%; WeightedF1: 77.02%
# Index: 11000; Accuracy: 82.51%; WeightedF1: 77.03%
# Index: 12000; Accuracy: 81.94%; WeightedF1: 78.15%
# Index: 13000; Accuracy: 81.48%; WeightedF1: 78.73%
# Index: 14000; Accuracy: 81.21%; WeightedF1: 79.23%
# Index: 15000; Accuracy: 80.85%; WeightedF1: 79.36%
# Index: 16000; Accuracy: 80.71%; WeightedF1: 79.57%
# Index: 17000; Accuracy: 80.51%; WeightedF1: 79.63%
# Index: 18000; Accuracy: 80.63%; WeightedF1: 79.93%
# Index: 19000; Accuracy: 80.46%; WeightedF1: 79.93%
# Index: 20000; Accuracy: 80.43%; WeightedF1: 80.01%
# Index: 21000; Accuracy: 80.36%; WeightedF1: 80.02%
# Index: 22000; Accuracy: 80.14%; WeightedF1: 79.89%
# Index: 23000; Accuracy: 80.11%; WeightedF1: 79.92%
# Index: 24000; Accuracy: 80.06%; WeightedF1: 79.92%
# Index: 25000; Accuracy: 79.95%; WeightedF1: 79.85%
# Index: 26000; Accuracy: 79.96%; WeightedF1: 79.90%
# Index: 27000; Accuracy: 79.99%; WeightedF1: 79.96%
# Index: 28000; Accuracy: 80.02%; WeightedF1: 80.01%
# Index: 29000; Accuracy: 79.99%; WeightedF1: 80.00%
# Index: 30000; Accuracy: 79.91%; WeightedF1: 79.93%
# Index: 31000; Accuracy: 79.86%; WeightedF1: 79.90%
# Index: 32000; Accuracy: 79.84%; WeightedF1: 79.89%
# Index: 33000; Accuracy: 79.80%; WeightedF1: 79.87%
# Index: 177000; Accuracy: 80.69%; WeightedF1: 80.70%
# Index: 178000; Accuracy: 80.68%; WeightedF1: 80.69%
# Index: 179000; Accuracy: 80.67%; WeightedF1: 80.68%
# Index: 180000; Accuracy: 80.67%; WeightedF1: 80.68%
# Index: 181000; Accuracy: 80.69%; WeightedF1: 80.69%
# Index: 182000; Accuracy: 80.69%; WeightedF1: 80.70%
# Index: 183000; Accuracy: 80.69%; WeightedF1: 80.70%
# Index: 184000; Accuracy: 80.70%; WeightedF1: 80.71%
# Index: 185000; Accuracy: 80.72%; WeightedF1: 80.73%
# Index: 186000; Accuracy: 80.72%; WeightedF1: 80.72%
# Index: 187000; Accuracy: 80.72%; WeightedF1: 80.73%
# Index: 188000; Accuracy: 80.72%; WeightedF1: 80.72%
# Index: 189000; Accuracy: 80.72%; WeightedF1: 80.72%
# Index: 190000; Accuracy: 80.72%; WeightedF1: 80.72%
# Index: 191000; Accuracy: 80.71%; WeightedF1: 80.71%
# Index: 192000; Accuracy: 80.70%; WeightedF1: 80.70%
# Index: 193000; Accuracy: 80.71%; WeightedF1: 80.71%
# Index: 194000; Accuracy: 80.72%; WeightedF1: 80.73%
# Index: 195000; Accuracy: 80.72%; WeightedF1: 80.72%
# Index: 196000; Accuracy: 80.72%; WeightedF1: 80.72%
#
#
#
# Debug pipeline:
# 0. Input
# --------
# AGEP: 54 (int)
# ANC: 4 (str)
# CIT: 5 (str)
# DEAR: 2 (str)
# DEYE: 2 (str)
# DIS: 2 (str)
# DREM: 2 (str)
# ESP: 0 (str)
# MAR: 1 (str)
# MIG: 3 (str)
# MIL: 4 (str)
# NATIVITY: 2 (str)
# RAC1P: 1 (str)
# RELP: 6 (str)
# SCHL: 21 (int)
# SEX: 2 (str)
#
# 1. Transformer union
# --------------------
#     1.0 ['MAR'] + ['RELP'] + ['DIS'] + ['ESP'] + ['CIT'] + ['MIG'] + ['MIL'] + ['ANC'] + ['NATIVITY'] + ['DEAR'] + ['DEYE'] + ['DREM'] + ['SEX'] + ['RAC1P'] | OneHotEncoder
#     ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#     ANC_1: 0 (int)
#     ANC_2: 0 (int)
#     ANC_3: 0 (int)
#     ANC_4: 1 (int)
#     CIT_1: 0 (int)
#     CIT_2: 0 (int)
#     CIT_3: 0 (int)
#     CIT_4: 0 (int)
#     CIT_5: 1 (int)
#     DEAR_1: 0 (int)
#     DEAR_2: 1 (int)
#     DEYE_1: 0 (int)
#     DEYE_2: 1 (int)
#     DIS_1: 0 (int)
#     DIS_2: 1 (int)
#     DREM_0: 0 (int)
#     DREM_1: 0 (int)
#     DREM_2: 1 (int)
#     ESP_0: 1 (int)
#     ESP_1: 0 (int)
#     ESP_2: 0 (int)
#     ESP_3: 0 (int)
#     ESP_4: 0 (int)
#     ESP_5: 0 (int)
#     ESP_6: 0 (int)
#     ESP_7: 0 (int)
#     ESP_8: 0 (int)
#     MAR_1: 1 (int)
#     MAR_2: 0 (int)
#     MAR_3: 0 (int)
#     MAR_4: 0 (int)
#     MAR_5: 0 (int)
#     MIG_0: 0 (int)
#     MIG_1: 0 (int)
#     MIG_2: 0 (int)
#     MIG_3: 1 (int)
#     MIL_0: 0 (int)
#     MIL_1: 0 (int)
#     MIL_2: 0 (int)
#     MIL_3: 0 (int)
#     MIL_4: 1 (int)
#     NATIVITY_1: 0 (int)
#     NATIVITY_2: 1 (int)
#     RAC1P_1: 1 (int)
#     RAC1P_2: 0 (int)
#     RAC1P_3: 0 (int)
#     RAC1P_4: 0 (int)
#     RAC1P_5: 0 (int)
#     RAC1P_6: 0 (int)
#     RAC1P_7: 0 (int)
#     RAC1P_8: 0 (int)
#     RAC1P_9: 0 (int)
#     RELP_0: 0 (int)
#     RELP_1: 0 (int)
#     RELP_10: 0 (int)
#     RELP_11: 0 (int)
#     RELP_12: 0 (int)
#     RELP_13: 0 (int)
#     RELP_14: 0 (int)
#     RELP_15: 0 (int)
#     RELP_16: 0 (int)
#     RELP_17: 0 (int)
#     RELP_2: 0 (int)
#     RELP_3: 0 (int)
#     RELP_4: 0 (int)
#     RELP_5: 0 (int)
#     RELP_6: 1 (int)
#     RELP_7: 0 (int)
#     RELP_8: 0 (int)
#     RELP_9: 0 (int)
#     SEX_1: 0 (int)
#     SEX_2: 1 (int)
#
#     1.1 Select
#     ----------
#     AGEP: 54 (int)
#
#     1.2 Select1
#     -----------
#     SCHL: 21 (int)
#
# AGEP: 54 (int)
# ANC_1: 0 (int)
# ANC_2: 0 (int)
# ANC_3: 0 (int)
# ANC_4: 1 (int)
# CIT_1: 0 (int)
# CIT_2: 0 (int)
# CIT_3: 0 (int)
# CIT_4: 0 (int)
# CIT_5: 1 (int)
# DEAR_1: 0 (int)
# DEAR_2: 1 (int)
# DEYE_1: 0 (int)
# DEYE_2: 1 (int)
# DIS_1: 0 (int)
# DIS_2: 1 (int)
# DREM_0: 0 (int)
# DREM_1: 0 (int)
# DREM_2: 1 (int)
# ESP_0: 1 (int)
# ESP_1: 0 (int)
# ESP_2: 0 (int)
# ESP_3: 0 (int)
# ESP_4: 0 (int)
# ESP_5: 0 (int)
# ESP_6: 0 (int)
# ESP_7: 0 (int)
# ESP_8: 0 (int)
# MAR_1: 1 (int)
# MAR_2: 0 (int)
# MAR_3: 0 (int)
# MAR_4: 0 (int)
# MAR_5: 0 (int)
# MIG_0: 0 (int)
# MIG_1: 0 (int)
# MIG_2: 0 (int)
# MIG_3: 1 (int)
# MIL_0: 0 (int)
# MIL_1: 0 (int)
# MIL_2: 0 (int)
# MIL_3: 0 (int)
# MIL_4: 1 (int)
# NATIVITY_1: 0 (int)
# NATIVITY_2: 1 (int)
# RAC1P_1: 1 (int)
# RAC1P_2: 0 (int)
# RAC1P_3: 0 (int)
# RAC1P_4: 0 (int)
# RAC1P_5: 0 (int)
# RAC1P_6: 0 (int)
# RAC1P_7: 0 (int)
# RAC1P_8: 0 (int)
# RAC1P_9: 0 (int)
# RELP_0: 0 (int)
# RELP_1: 0 (int)
# RELP_10: 0 (int)
# RELP_11: 0 (int)
# RELP_12: 0 (int)
# RELP_13: 0 (int)
# RELP_14: 0 (int)
# RELP_15: 0 (int)
# RELP_16: 0 (int)
# RELP_17: 0 (int)
# RELP_2: 0 (int)
# RELP_3: 0 (int)
# RELP_4: 0 (int)
# RELP_5: 0 (int)
# RELP_6: 1 (int)
# RELP_7: 0 (int)
# RELP_8: 0 (int)
# RELP_9: 0 (int)
# SCHL: 21 (int)
# SEX_1: 0 (int)
# SEX_2: 1 (int)
#
# 2. MinMaxScaler
# ---------------
# AGEP: 0.56842 (float)
# ANC_1: 0.00000 (float)
# ANC_2: 0.00000 (float)
# ANC_3: 0.00000 (float)
# ANC_4: 1.00000 (float)
# CIT_1: 0.00000 (float)
# CIT_2: 0.00000 (float)
# CIT_3: 0.00000 (float)
# CIT_4: 0.00000 (float)
# CIT_5: 1.00000 (float)
# DEAR_1: 0.00000 (float)
# DEAR_2: 1.00000 (float)
# DEYE_1: 0.00000 (float)
# DEYE_2: 1.00000 (float)
# DIS_1: 0.00000 (float)
# DIS_2: 1.00000 (float)
# DREM_0: 0.00000 (float)
# DREM_1: 0.00000 (float)
# DREM_2: 1.00000 (float)
# ESP_0: 1.00000 (float)
# ESP_1: 0.00000 (float)
# ESP_2: 0.00000 (float)
# ESP_3: 0.00000 (float)
# ESP_4: 0.00000 (float)
# ESP_5: 0.00000 (float)
# ESP_6: 0.00000 (float)
# ESP_7: 0.00000 (float)
# ESP_8: 0.00000 (float)
# MAR_1: 1.00000 (float)
# MAR_2: 0.00000 (float)
# MAR_3: 0.00000 (float)
# MAR_4: 0.00000 (float)
# MAR_5: 0.00000 (float)
# MIG_0: 0.00000 (float)
# MIG_1: 0.00000 (float)
# MIG_2: 0.00000 (float)
# MIG_3: 1.00000 (float)
# MIL_0: 0.00000 (float)
# MIL_1: 0.00000 (float)
# MIL_2: 0.00000 (float)
# MIL_3: 0.00000 (float)
# MIL_4: 1.00000 (float)
# NATIVITY_1: 0.00000 (float)
# NATIVITY_2: 1.00000 (float)
# RAC1P_1: 1.00000 (float)
# RAC1P_2: 0.00000 (float)
# RAC1P_3: 0.00000 (float)
# RAC1P_4: 0.00000 (float)
# RAC1P_5: 0.00000 (float)
# RAC1P_6: 0.00000 (float)
# RAC1P_7: 0.00000 (float)
# RAC1P_8: 0.00000 (float)
# RAC1P_9: 0.00000 (float)
# RELP_0: 0.00000 (float)
# RELP_1: 0.00000 (float)
# RELP_10: 0.00000 (float)
# RELP_11: 0.00000 (float)
# RELP_12: 0.00000 (float)
# RELP_13: 0.00000 (float)
# RELP_14: 0.00000 (float)
# RELP_15: 0.00000 (float)
# RELP_16: 0.00000 (float)
# RELP_17: 0.00000 (float)
# RELP_2: 0.00000 (float)
# RELP_3: 0.00000 (float)
# RELP_4: 0.00000 (float)
# RELP_5: 0.00000 (float)
# RELP_6: 1.00000 (float)
# RELP_7: 0.00000 (float)
# RELP_8: 0.00000 (float)
# RELP_9: 0.00000 (float)
# SCHL: 0.87500 (float)
# SEX_1: 0.00000 (float)
# SEX_2: 1.00000 (float)
#
# 3. AdaptiveRandomForestClassifier
# ---------------------------------
#
# 0: 0.33687
# 1: 0.66313
#
#
# Confusion matrix:
#      0        1
# 0   79,529   25,968
# 1   12,003   79,466
#
# Confusion matrix dict:
#  {1: {0: 12003.0, 1: 79466.0}, 0: {1: 25968.0, 0: 79529.0}}

# %% [markdown]
# #### Predict with Streaming Random Patches ensemble classifier

# %%
base_model = tree.HoeffdingTreeClassifier(
     grace_period=50, delta=0.01
)
SRP_model_obj = ensemble.SRPClassifier(
     model=base_model, n_models=3, seed=42
)
SRP_model = transform_pipeline | SRP_model_obj
evaluate_binary_model(dataset, SRP_model, dataset_limit=60_000)
# Out:
# Index: 1000; Accuracy: 82.28%; WeightedF1: 79.43%
# Index: 2000; Accuracy: 80.54%; WeightedF1: 77.74%
# Index: 3000; Accuracy: 80.49%; WeightedF1: 77.32%
# Index: 4000; Accuracy: 81.17%; WeightedF1: 78.06%
# Index: 5000; Accuracy: 81.68%; WeightedF1: 78.59%
# Index: 6000; Accuracy: 82.08%; WeightedF1: 79.11%
# Index: 7000; Accuracy: 82.64%; WeightedF1: 79.88%
# Index: 8000; Accuracy: 82.92%; WeightedF1: 80.30%
# Index: 9000; Accuracy: 82.81%; WeightedF1: 80.17%
# Index: 10000; Accuracy: 83.03%; WeightedF1: 80.43%
# Index: 11000; Accuracy: 82.55%; WeightedF1: 80.29%
# Index: 12000; Accuracy: 82.17%; WeightedF1: 80.42%
# Index: 13000; Accuracy: 81.70%; WeightedF1: 80.30%
# Index: 14000; Accuracy: 81.19%; WeightedF1: 80.07%
# Index: 15000; Accuracy: 80.93%; WeightedF1: 79.99%
# Index: 16000; Accuracy: 80.76%; WeightedF1: 80.00%
# Index: 17000; Accuracy: 80.73%; WeightedF1: 80.12%
# Index: 18000; Accuracy: 80.83%; WeightedF1: 80.32%
# Index: 19000; Accuracy: 80.84%; WeightedF1: 80.43%
# Index: 20000; Accuracy: 80.73%; WeightedF1: 80.39%
# Index: 21000; Accuracy: 80.70%; WeightedF1: 80.40%
# Index: 22000; Accuracy: 80.58%; WeightedF1: 80.32%
# Index: 23000; Accuracy: 80.54%; WeightedF1: 80.31%
# Index: 24000; Accuracy: 80.54%; WeightedF1: 80.35%
# Index: 25000; Accuracy: 80.48%; WeightedF1: 80.33%
# Index: 26000; Accuracy: 80.51%; WeightedF1: 80.38%
# Index: 27000; Accuracy: 80.52%; WeightedF1: 80.41%
# Index: 28000; Accuracy: 80.52%; WeightedF1: 80.42%
# Index: 29000; Accuracy: 80.41%; WeightedF1: 80.32%
# Index: 30000; Accuracy: 80.32%; WeightedF1: 80.24%
# Index: 31000; Accuracy: 80.35%; WeightedF1: 80.27%
# Index: 32000; Accuracy: 80.28%; WeightedF1: 80.22%
# Index: 33000; Accuracy: 80.28%; WeightedF1: 80.24%
# Index: 34000; Accuracy: 80.24%; WeightedF1: 80.20%
# Index: 35000; Accuracy: 80.20%; WeightedF1: 80.16%
# Index: 36000; Accuracy: 80.23%; WeightedF1: 80.20%
# Index: 37000; Accuracy: 80.23%; WeightedF1: 80.21%
# Index: 38000; Accuracy: 80.20%; WeightedF1: 80.19%
# Index: 39000; Accuracy: 80.18%; WeightedF1: 80.16%
# Index: 40000; Accuracy: 80.20%; WeightedF1: 80.19%
# Index: 41000; Accuracy: 80.21%; WeightedF1: 80.20%
# Index: 42000; Accuracy: 80.22%; WeightedF1: 80.22%
# Index: 43000; Accuracy: 80.25%; WeightedF1: 80.25%
# Index: 44000; Accuracy: 80.21%; WeightedF1: 80.21%
# Index: 45000; Accuracy: 80.22%; WeightedF1: 80.23%
# Index: 46000; Accuracy: 80.22%; WeightedF1: 80.23%
# Index: 47000; Accuracy: 80.21%; WeightedF1: 80.22%
# Index: 48000; Accuracy: 80.20%; WeightedF1: 80.22%
# Index: 49000; Accuracy: 80.25%; WeightedF1: 80.27%
# Index: 50000; Accuracy: 80.26%; WeightedF1: 80.27%
# Index: 51000; Accuracy: 80.31%; WeightedF1: 80.33%
# Index: 52000; Accuracy: 80.33%; WeightedF1: 80.36%
# Index: 53000; Accuracy: 80.35%; WeightedF1: 80.38%
# Index: 54000; Accuracy: 80.36%; WeightedF1: 80.38%
# Index: 55000; Accuracy: 80.41%; WeightedF1: 80.44%
# Index: 56000; Accuracy: 80.43%; WeightedF1: 80.45%
# Index: 57000; Accuracy: 80.46%; WeightedF1: 80.49%
# Index: 58000; Accuracy: 80.44%; WeightedF1: 80.47%
# Index: 59000; Accuracy: 80.47%; WeightedF1: 80.50%
# Index: 60000; Accuracy: 80.46%; WeightedF1: 80.49%
#
#
#
# Debug pipeline:
# 0. Input
# --------
# AGEP: 37 (int)
# ANC: 1 (str)
# CIT: 5 (str)
# DEAR: 2 (str)
# DEYE: 2 (str)
# DIS: 2 (str)
# DREM: 2 (str)
# ESP: 0 (str)
# MAR: 1 (str)
# MIG: 1 (str)
# MIL: 4 (str)
# NATIVITY: 2 (str)
# RAC1P: 1 (str)
# RELP: 1 (str)
# SCHL: 19 (int)
# SEX: 1 (str)
#
# 1. Transformer union
# --------------------
#     1.0 ['MAR'] + ['RELP'] + ['DIS'] + ['ESP'] + ['CIT'] + ['MIG'] + ['MIL'] + ['ANC'] + ['NATIVITY'] + ['DEAR'] + ['DEYE'] + ['DREM'] + ['SEX'] + ['RAC1P'] | OneHotEncoder
#     ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#     ANC_1: 1 (int)
#     ANC_2: 0 (int)
#     ANC_3: 0 (int)
#     ANC_4: 0 (int)
#     CIT_1: 0 (int)
#     CIT_2: 0 (int)
#     CIT_3: 0 (int)
#     CIT_4: 0 (int)
#     CIT_5: 1 (int)
#     DEAR_1: 0 (int)
#     DEAR_2: 1 (int)
#     DEYE_1: 0 (int)
#     DEYE_2: 1 (int)
#     DIS_1: 0 (int)
#     DIS_2: 1 (int)
#     DREM_0: 0 (int)
#     DREM_1: 0 (int)
#     DREM_2: 1 (int)
#     ESP_0: 1 (int)
#     ESP_1: 0 (int)
#     ESP_2: 0 (int)
#     ESP_3: 0 (int)
#     ESP_4: 0 (int)
#     ESP_5: 0 (int)
#     ESP_6: 0 (int)
#     ESP_7: 0 (int)
#     ESP_8: 0 (int)
#     MAR_1: 1 (int)
#     MAR_2: 0 (int)
#     MAR_3: 0 (int)
#     MAR_4: 0 (int)
#     MAR_5: 0 (int)
#     MIG_0: 0 (int)
#     MIG_1: 1 (int)
#     MIG_2: 0 (int)
#     MIG_3: 0 (int)
#     MIL_0: 0 (int)
#     MIL_1: 0 (int)
#     MIL_2: 0 (int)
#     MIL_3: 0 (int)
#     MIL_4: 1 (int)
#     NATIVITY_1: 0 (int)
#     NATIVITY_2: 1 (int)
#     RAC1P_1: 1 (int)
#     RAC1P_2: 0 (int)
#     RAC1P_3: 0 (int)
#     RAC1P_4: 0 (int)
#     RAC1P_5: 0 (int)
#     RAC1P_6: 0 (int)
#     RAC1P_7: 0 (int)
#     RAC1P_8: 0 (int)
#     RAC1P_9: 0 (int)
#     RELP_0: 0 (int)
#     RELP_1: 1 (int)
#     RELP_10: 0 (int)
#     RELP_11: 0 (int)
#     RELP_12: 0 (int)
#     RELP_13: 0 (int)
#     RELP_14: 0 (int)
#     RELP_15: 0 (int)
#     RELP_16: 0 (int)
#     RELP_17: 0 (int)
#     RELP_2: 0 (int)
#     RELP_3: 0 (int)
#     RELP_4: 0 (int)
#     RELP_5: 0 (int)
#     RELP_6: 0 (int)
#     RELP_7: 0 (int)
#     RELP_8: 0 (int)
#     RELP_9: 0 (int)
#     SEX_1: 1 (int)
#     SEX_2: 0 (int)
#
#     1.1 Select
#     ----------
#     AGEP: 37 (int)
#
#     1.2 Select1
#     -----------
#     SCHL: 19 (int)
#
# AGEP: 37 (int)
# ANC_1: 1 (int)
# ANC_2: 0 (int)
# ANC_3: 0 (int)
# ANC_4: 0 (int)
# CIT_1: 0 (int)
# CIT_2: 0 (int)
# CIT_3: 0 (int)
# CIT_4: 0 (int)
# CIT_5: 1 (int)
# DEAR_1: 0 (int)
# DEAR_2: 1 (int)
# DEYE_1: 0 (int)
# DEYE_2: 1 (int)
# DIS_1: 0 (int)
# DIS_2: 1 (int)
# DREM_0: 0 (int)
# DREM_1: 0 (int)
# DREM_2: 1 (int)
# ESP_0: 1 (int)
# ESP_1: 0 (int)
# ESP_2: 0 (int)
# ESP_3: 0 (int)
# ESP_4: 0 (int)
# ESP_5: 0 (int)
# ESP_6: 0 (int)
# ESP_7: 0 (int)
# ESP_8: 0 (int)
# MAR_1: 1 (int)
# MAR_2: 0 (int)
# MAR_3: 0 (int)
# MAR_4: 0 (int)
# MAR_5: 0 (int)
# MIG_0: 0 (int)
# MIG_1: 1 (int)
# MIG_2: 0 (int)
# MIG_3: 0 (int)
# MIL_0: 0 (int)
# MIL_1: 0 (int)
# MIL_2: 0 (int)
# MIL_3: 0 (int)
# MIL_4: 1 (int)
# NATIVITY_1: 0 (int)
# NATIVITY_2: 1 (int)
# RAC1P_1: 1 (int)
# RAC1P_2: 0 (int)
# RAC1P_3: 0 (int)
# RAC1P_4: 0 (int)
# RAC1P_5: 0 (int)
# RAC1P_6: 0 (int)
# RAC1P_7: 0 (int)
# RAC1P_8: 0 (int)
# RAC1P_9: 0 (int)
# RELP_0: 0 (int)
# RELP_1: 1 (int)
# RELP_10: 0 (int)
# RELP_11: 0 (int)
# RELP_12: 0 (int)
# RELP_13: 0 (int)
# RELP_14: 0 (int)
# RELP_15: 0 (int)
# RELP_16: 0 (int)
# RELP_17: 0 (int)
# RELP_2: 0 (int)
# RELP_3: 0 (int)
# RELP_4: 0 (int)
# RELP_5: 0 (int)
# RELP_6: 0 (int)
# RELP_7: 0 (int)
# RELP_8: 0 (int)
# RELP_9: 0 (int)
# SCHL: 19 (int)
# SEX_1: 1 (int)
# SEX_2: 0 (int)
#
# 2. MinMaxScaler
# ---------------
# AGEP: 0.38947 (float)
# ANC_1: 1.00000 (float)
# ANC_2: 0.00000 (float)
# ANC_3: 0.00000 (float)
# ANC_4: 0.00000 (float)
# CIT_1: 0.00000 (float)
# CIT_2: 0.00000 (float)
# CIT_3: 0.00000 (float)
# CIT_4: 0.00000 (float)
# CIT_5: 1.00000 (float)
# DEAR_1: 0.00000 (float)
# DEAR_2: 1.00000 (float)
# DEYE_1: 0.00000 (float)
# DEYE_2: 1.00000 (float)
# DIS_1: 0.00000 (float)
# DIS_2: 1.00000 (float)
# DREM_0: 0.00000 (float)
# DREM_1: 0.00000 (float)
# DREM_2: 1.00000 (float)
# ESP_0: 1.00000 (float)
# ESP_1: 0.00000 (float)
# ESP_2: 0.00000 (float)
# ESP_3: 0.00000 (float)
# ESP_4: 0.00000 (float)
# ESP_5: 0.00000 (float)
# ESP_6: 0.00000 (float)
# ESP_7: 0.00000 (float)
# ESP_8: 0.00000 (float)
# MAR_1: 1.00000 (float)
# MAR_2: 0.00000 (float)
# MAR_3: 0.00000 (float)
# MAR_4: 0.00000 (float)
# MAR_5: 0.00000 (float)
# MIG_0: 0.00000 (float)
# MIG_1: 1.00000 (float)
# MIG_2: 0.00000 (float)
# MIG_3: 0.00000 (float)
# MIL_0: 0.00000 (float)
# MIL_1: 0.00000 (float)
# MIL_2: 0.00000 (float)
# MIL_3: 0.00000 (float)
# MIL_4: 1.00000 (float)
# NATIVITY_1: 0.00000 (float)
# NATIVITY_2: 1.00000 (float)
# RAC1P_1: 1.00000 (float)
# RAC1P_2: 0.00000 (float)
# RAC1P_3: 0.00000 (float)
# RAC1P_4: 0.00000 (float)
# RAC1P_5: 0.00000 (float)
# RAC1P_6: 0.00000 (float)
# RAC1P_7: 0.00000 (float)
# RAC1P_8: 0.00000 (float)
# RAC1P_9: 0.00000 (float)
# RELP_0: 0.00000 (float)
# RELP_1: 1.00000 (float)
# RELP_10: 0.00000 (float)
# RELP_11: 0.00000 (float)
# RELP_12: 0.00000 (float)
# RELP_13: 0.00000 (float)
# RELP_14: 0.00000 (float)
# RELP_15: 0.00000 (float)
# RELP_16: 0.00000 (float)
# RELP_17: 0.00000 (float)
# RELP_2: 0.00000 (float)
# RELP_3: 0.00000 (float)
# RELP_4: 0.00000 (float)
# RELP_5: 0.00000 (float)
# RELP_6: 0.00000 (float)
# RELP_7: 0.00000 (float)
# RELP_8: 0.00000 (float)
# RELP_9: 0.00000 (float)
# SCHL: 0.79167 (float)
# SEX_1: 1.00000 (float)
# SEX_2: 0.00000 (float)
#
# 3. SRPClassifier(HoeffdingTreeClassifier)
# -----------------------------------------
#
# 0: 0.09620
# 1: 0.90380
#
#
# Confusion matrix:
#      0        1
# 0   28,258    6,166
# 1    5,559   20,016
#
# Confusion matrix dict:
#  {1: {0: 5559.0, 1: 20016.0}, 0: {1: 6166.0, 0: 28258.0}}
